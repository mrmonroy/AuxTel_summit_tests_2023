# %% [markdown]
# # List of Exposures from RubinTV file
#
#
# - work with Weakly_2023_35
# - use jupyter kernel LSST
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2023/09/13
# - last update : 2023/09/13

# %%
import sys
print(sys.executable)
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/bin/python3

# %%
print(sys.path)
# Out:
# ['/sdf/data/rubin/user/dagoret/AuxTel_summit_tests_2023/butlertools', '/home/d/dagoret/repos/repos_w_2023_35/analysis_tools/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/cp_pipe/g857a3418e4+7df23b908a/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/shapelet/g44018dc512+ea6441928c/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_modelfit/g93c4d6e787+79b822255a/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/scarlet_extensions/g9d18589735+d445b4966c/lib/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/proxmin/g33b4157f25/lib/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/scarlet/g63ff1f842d+4083830bf8/lib/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_scarlet/g943cb464a2+f79590064d/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/psfex/gc054bea089+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_psfex/g58be5f913a+32f1932512/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_piff/gc86a011abf+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_gaap/g8dd6597355+dceeeb951c/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_photometryKron/gb2715bf1a1+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_convolved/g42fff21dfb+94f62ec815/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/kht/gafcb7142de/cpp/build', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/verify_metrics/gd129bed42c+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/felis/g56b87fd2ae+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/dax_apdb/g4c90b7bd52+fc57afb704/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/verify/gffb8816710+02c788d496/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_deblender/g2cc88a2952+6327360372/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_shapeHSM/g571dde35ae+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_trailedSources/g47da3c6c86+f7136a40d1/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_astrom/g0a0026dc87+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ip_diffim/g07994bdeae+16b1756208/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/dustmaps_cachedata/gbb0a0c949e+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/coadd_utils/g337abbeb29+ea6441928c/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/pipe_tasks/g68a3911fdd+6ad9f154ac/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/astro_metadata_translator/g0978aabd1f+2a7d2c9fe3/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/obs_base/gcc620a9fd9+e9a6d3d3e6/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/skymap/g37c6e7c3d5+905c2c68d7/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_base/g67924a670a+edc5793283/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_algorithms/g6f40f426a6+f7136a40d1/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ip_isr/gba31a79951+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/daf_relation/g8a20fa5453+e358f92434/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/resources/g9e435448e7+e35 ...

# %%
! eups list -s | grep LOCAL
# Out:
# analysis_tools        LOCAL:/home/d/dagoret/repos/repos_w_2023_35/analysis_tools 	setup
# atmospec              LOCAL:/home/d/dagoret/repos/repos_w_2023_35/atmospec 	setup
# eups                  LOCAL:/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/eups 	setup
# spectractor           LOCAL:/home/d/dagoret/repos/repos_w_2023_35/Spectractor 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
# Weekly 2023_35
#    g4213664e8e+c55b99ec95 	current w_2023_35 setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits
from astropy.time import Time

# %%
from IPython.display import display, HTML

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
#repo = "/sdf/group/rubin/repo/main"
repo="/sdf/group/rubin/repo/oga/"
butler = dafButler.Butler(repo)
registry = butler.registry

# %%
collection='LATISS/raw/all'

# %% [markdown]
# ## Input file

# %%
# !ls files_for_data
# Out:
# auxtel_2023_09_12.json

# %%
path = "files_for_data"
file_rubintv = "auxtel_2023_09_12.json"
fullfilename_rubintv = os.path.join(path,file_rubintv)

# %%
df_in = pd.read_json(fullfilename_rubintv)

# %%
df_in
# Out:
#                                               1                 2    \
# Exposure id                         2023091200001     2023091200002
# Exposure time                                   0                 2
# Darktime                                 0.011569           2.23556
# Image type                                   bias           engtest
# Observation reason                           bias           engtest
# dayObs                                   20230912          20230912
# seqNum                                          1                 2
# Group id                         2744773622920000  2744773677250000
# Target                              Park position     Park position
# Science program                           unknown           unknown
# RA                                     307.806729        307.806729
# Dec                                    -20.258929        -20.258929
# Sky angle                                    None        100.228622
# Azimuth                                 359.82388         359.82388
# Zenith angle                            10.063331         10.063331
# TAI                                      19:42:42          19:42:50
# Filter                                 collimator             empty
# Disperser                               holo4_001             empty
# Airmass                                      None                 0
# Focus-Z                                         0                 0
# Altitude                                79.936669         79.936669
# DIMM Seeing                                  None              None
# Mount jitter RMS                              NaN               NaN
# Mount motion image degradation                NaN               NaN
# 50-sigma source count                         NaN               NaN
# _50-sigma source count                        NaN               NaN
# _Mount motion image degradation               NaN               NaN
# Log message                                   NaN               NaN
# Log level                                     NaN               NaN
# Jira ticket                                   NaN               NaN
# Quality flag                                  NaN               NaN
# Has annotations?                              NaN               NaN
#
#                                                 3                   4    \
# Exposure id                           2023091200003       2023091200004
# Exposure time                                     2                   2
# Darktime                                    2.23442             2.24144
# Image type                                  engtest             engtest
# Observation reason                          engtest             engtest
# dayObs                                     20230912            20230912
# seqNum                                            3                   4
# Group id                           2744785664300000    2744787400740000
# Target                           DaytimeCheckout001  DaytimeCheckout002
# Science program                             unknown             unknown
# RA                                       250.956914           221.58633
# Dec                                        4.386003          -20.145775
# Sky angle                                172.740192          100.034998
# Azimuth                                   44.784582          359.099669
# Zenith angle                              44.867869            9.999076
# TAI                                        20:02:46            20:05:42
# Filter                                        empty          collimator
# Disperser                                     empty     blue300lpmm_qn1
# Airmass                                    1.408314            1.015183
# Focus-Z                                           0                   0
# Altitude                                  45.132131           80.000924
# DIMM Seeing                                    None                None
# Mount jitter RMS                           0.032052            0.043537
# Mount motion image degradation             0.029619            0.009012
# 50-sigma source count                           NaN                 NaN
# _50-sigma source count                          NaN                 NaN
# _Mount motion image degradation                 NaN                 NaN
# Log message                                     NaN                 NaN
# Log level                                       NaN                 NaN
# Jira ticket                                     NaN                 NaN
# Quality flag                                    NaN                 NaN
# Has annotations?                                NaN                 NaN
#
#                                                 5                   6    \
# Exposure id                           2023091200005       2023091200006
# Exposure time                                     0                   0
# Darktime                                   0.011483            0.007931
# Image type                                     bias                bias
# Observation reason                             bias                bias
# dayObs                                     20230912            20230912
# seqNum                                            5                   6
# Group id                           2744831792910000    2744831817950000
# Target                           FlatField position  FlatField position
# Science program                             unknown             unknown
# RA                                       230.643065          230.655415
# Dec                                      -81.143132          -81.143234
# Sky angle                                      None                None
# Azimuth                                  181.764156          181.764148
# Zenith angle                              51.092568           51.092649
# TAI                                        21:19:39            21:19:41
# Filter                                   SDSSr_65mm          SDSSr_65mm
# Disperser                                     empty               empty
# Airmass                                        None                None
# Focus-Z                                           0                   0
# Altitude                                  38.907432           38.907351
# DIMM Seeing                                    None                None
# Mount jitter RMS                                NaN                 NaN
# Mount motion image degradation                  NaN                 NaN
# 50-sigma source count                           NaN                 NaN
# _50-sigma source count                          NaN                 NaN
# _Mount motion image degradation                 NaN                 NaN
# Log message                                     NaN                 NaN
# Log level                                       NaN                 NaN
# Jira ticket                                     NaN                 NaN
# Quality flag                                    NaN                 NaN
# Has annotations?                                NaN                 NaN
#
#                                                 7                   8    \
# Exposure id                           2023091200007       2023091200008
# Exposure time                                     0                   0
# Darktime                                   0.008454            0.009334
# Image type                                     bias                bias
# Observation reason                             bias                bias
# dayObs                                     20230912            20230912
# seqNum                                            7                   8
# Group id                           2744831843010000    2744831868040000
# Target                           FlatField position  FlatField position
# Science program                             unknown             unknown
# RA                                       230.663626          230.675982
# Dec                                      -81.143297          -81.143388
# Sky angle                                      None                None
# Azimuth                                  181.764149          181.764142
# Zenith angle                              51.092699           51.092769
# TAI                                        21:19:44            21:19:46
# Filter                                   SDSSr_65mm          SDSSr_65mm
# Disperser                                     empty               empty
# Airmass                                        None                None
# Focus-Z                                           0                   0
# Altitude                                  38.907301           38.907231
# DIMM Seeing                                    None                None
# Mount jitter RMS                                NaN                 NaN
# Mount motion image degradation                  NaN                 NaN
# 50-sigma source count                           NaN                 NaN
# _50-sigma source count                          NaN                 NaN
# _Mount motion image degradation                 NaN                 NaN
# Log message                                     NaN                 NaN
# Log level                                       NaN                 NaN
# Jira ticket                                     NaN                 NaN
# Quality flag                                    NaN                 NaN
# Has annotations?                                NaN                 NaN
#
#                                                 9                   10   ...  \
# Exposure id                           2023091200009       2023091200010  ...
# Exposure time                                     0                   0  ...
# Darktime                                   0.007617             0.00798  ...
# Image type                                     bias                bias  ...
# Observation reason                             bias                bias  ...
# dayObs                                     20230912            20230912  ...
# seqNum                                            9                  10  ...
# Group id                           2744831893070000    2744831918110000  ...
# Target                           FlatField position  FlatField position  ...
# Science program                             unknown             unknown  ...
# RA                                       230.684182          230.696546  ...
# Dec                                      -81.143445           -81.14353  ...
# Sky angle                                      None                None  ...
# Azimuth                                  181.764146           181.76414  ...
# Zenith angle                              51.092813           51.092883  ...
# TAI                                        21:19:49            21:19:51  ...
# Filter                                   SDSSr_65mm          SDSSr_65mm  ...
# Disperser                                     empty               empty  ...
# Airmass                                        None                None  ...
# Focus-Z                                           0                   0  ...
# Altitude                                  38.907187           38.907117  ...
# DIMM Seeing                                    None                None  ...
# Mount jitter RMS                                NaN                 NaN  ...
# Mount motion image degradation                  NaN                 NaN  ...
# 50-sigma source count                           NaN                 NaN  ...
# _50-sigma source count                          NaN                 NaN  ...
# _Mount motion image degradation                 NaN                 NaN  ...
# Log message                                     NaN                 NaN  ...
# Log level                                       NaN                 NaN  ...
# Jira ticket                                     NaN                 NaN  ...
# Quality flag                                    NaN                 NaN  ...
# Has annotations?                                NaN                 NaN  ...
#
#                                               425               426  \
# Exposure id                         2023091200425     2023091200426
# Exposure time                                  30                30
# Darktime                                  30.2468           30.2269
# Image type                                science           science
# Observation reason                         object            object
# dayObs                                   20230912          20230912
# seqNum                                        425               426
# Group id                         2745102492280000  2745102492280000
# Target                                     HD2811            HD2811
# Science program                       SITCOM-1001       SITCOM-1001
# RA                                        7.87485          7.874744
# Dec                                    -43.578505        -43.578435
# Sky angle                               46.235648         46.235801
# Azimuth                                146.261365        146.606702
# Zenith angle                            16.567957         16.482061
# TAI                                      04:58:10          04:58:53
# Filter                                 collimator        collimator
# Disperser                               holo4_003         holo4_003
# Airmass                                   1.04304          1.042579
# Focus-Z                                 -0.054788         -0.054788
# Altitude                                73.432043         73.517939
# DIMM Seeing                                  None              None
# Mount jitter RMS                         0.180895           0.21811
# Mount motion image degradation           0.114329          0.116371
# 50-sigma source count                         NaN               NaN
# _50-sigma source count                        NaN               NaN
# _Mount motion image degradation               NaN               NaN
# Log message                                   NaN               NaN
# Log level                                     NaN               NaN
# Jira ticket                                   NaN               NaN
# Quality flag                                  NaN               NaN
# Has annotations?                              NaN               NaN
#
#                                               427               428  \
# Exposure id                         2023091200427     2023091200428
# Exposure time                                  20                20
# Darktime                                  20.2406           20.2331
# Image type                                science           science
# Observation reason                         object            object
# dayObs                                   20230912          20230912
# seqNum                                        427               428
# Group id                         2745102492280000  2745102492280000
# Target                                     HD2811            HD2811
# Science program                       SITCOM-1001       SITCOM-1001
# RA                                       7.874792           7.87472
# Dec                                    -43.578463        -43.578408
# Sky angle                               46.235687         46.235811
# Azimuth                                147.021594        147.293217
# Zenith angle                            16.381372         16.316714
# TAI                                      04:59:43          05:00:16
# Filter                                 collimator        collimator
# Disperser                         blue300lpmm_qn1   blue300lpmm_qn1
# Airmass                                  1.042049          1.041706
# Focus-Z                                 -0.054788         -0.054788
# Altitude                                73.618628         73.683286
# DIMM Seeing                                  None              None
# Mount jitter RMS                         0.185571           0.19517
# Mount motion image degradation           0.087545          0.133185
# 50-sigma source count                         NaN               NaN
# _50-sigma source count                        NaN               NaN
# _Mount motion image degradation               NaN               NaN
# Log message                                   NaN               NaN
# Log level                                     NaN               NaN
# Jira ticket                                   NaN               NaN
# Quality flag                                  NaN               NaN
# Has annotations?                              NaN               NaN
#
#                                               429               430  \
# Exposure id                         2023091200429     2023091200430
# Exposure time                                  20                20
# Darktime                                  20.2471           20.2349
# Image type                                science           science
# Observation reason                         object            object
# dayObs                                   20230912          20230912
# seqNum                                        429               430
# Group id                         2745102492280000  2745102492280000
# Target                                     HD2811            HD2811
# Science program                       SITCOM-1001       SITCOM-1001
# RA                                       7.874844          7.874799
# Dec                                    -43.578501        -43.578484
# Sky angle                                 46.2356         46.235686
# Azimuth                                147.567262        147.852295
# Zenith angle                            16.252739         16.187162
# TAI                                      05:00:49          05:01:24
# Filter                                 collimator             empty
# Disperser                         blue300lpmm_qn1   blue300lpmm_qn1
# Airmass                                  1.041367          1.041014
# Focus-Z                                 -0.054788         -0.054788
# Altitude                                73.747261         73.812838
# DIMM Seeing                                  None              None
# Mount jitter RMS                          0.18814          0.180523
# Mount motion image degradation           0.082596          0.130715
# 50-sigma source count                         NaN               NaN
# _50-sigma source count                        NaN               NaN
# _Mount motion image degradation               NaN               NaN
# Log message                                   NaN               NaN
# Log level                                     NaN               NaN
# Jira ticket                                   NaN               NaN
# Quality flag                                  NaN               NaN
# Has annotations?                              NaN               NaN
#
#                                               431               432  \
# Exposure id                         2023091200431     2023091200432
# Exposure time                                  20                20
# Darktime                                  20.2428           20.2329
# Image type                                science           science
# Observation reason                         object            object
# dayObs                                   20230912          20230912
# seqNum                                        431               432
# Group id                         2745102492280000  2745102492280000
# Target                                     HD2811            HD2811
# Science program                       SITCOM-1001       SITCOM-1001
# RA                                       7.874755          7.874794
# Dec                                     -43.57843        -43.578453
# Sky angle                               46.235692         46.235574
# Azimuth                                148.131393           148.413
# Zenith angle                            16.123981         16.061393
# TAI                                      05:01:57          05:02:30
# Filter                                      empty             empty
# Disperser                         blue300lpmm_qn1   blue300lpmm_qn1
# Airmass                                  1.040685          1.040358
# Focus-Z                                 -0.054788         -0.054788
# Altitude                                73.876019         73.938607
# DIMM Seeing                                  None              None
# Mount jitter RMS                         0.191078          0.231543
# Mount motion image degradation            0.09226          0.102844
# 50-sigma source count                         NaN               NaN
# _50-sigma source count                        NaN               NaN
# _Mount motion image degradation               NaN               NaN
# Log message                                   NaN               NaN
# Log level                                     NaN               NaN
# Jira ticket                                   NaN               NaN
# Quality flag                                  NaN               NaN
# Has annotations?                              NaN               NaN
#
#                                               433               434
# Exposure id                         2023091200433     2023091200434
# Exposure time                                   5                 5
# Darktime                                  5.24483           5.23773
# Image type                                    acq               acq
# Observation reason                            acq               acq
# dayObs                                   20230912          20230912
# seqNum                                        433               434
# Group id                         2745109835900000  2745109835900000
# Target                                   HD185975          HD185975
# Science program                       SITCOM-1001       SITCOM-1001
# RA                                      307.07624        307.726665
# Dec                                    -87.472268        -87.505242
# Sky angle                              140.888868         140.88384
# Azimuth                                182.251517        182.205047
# Zenith angle                            57.984913         57.988535
# TAI                                      05:03:44          05:04:17
# Filter                                      empty             empty
# Disperser                               holo4_003         holo4_003
# Airmass                                  1.879706          1.879896
# Focus-Z                                 -0.054788         -0.054788
# Altitude                                32.015087         32.011465
# DIMM Seeing                                  None              None
# Mount jitter RMS                         0.112853          0.086058
# Mount motion image degradation           0.112593          0.085174
# 50-sigma source count                         NaN               NaN
# _50-sigma source count                        NaN               NaN
# _Mount motion image degradation               NaN               NaN
# Log message                                   NaN               NaN
# Log level                                     NaN               NaN
# Jira ticket                                   NaN               NaN
# Quality flag                                  NaN               NaN
# Has annotations?                              NaN               NaN
#
# [32 rows x 434 columns]

# %%
df_in_transposed = df_in.T

# %%
df_in_transposed
# Out:
#        Exposure id Exposure time  Darktime Image type Observation reason  \
# 1    2023091200001             0  0.011569       bias               bias
# 2    2023091200002             2   2.23556    engtest            engtest
# 3    2023091200003             2   2.23442    engtest            engtest
# 4    2023091200004             2   2.24144    engtest            engtest
# 5    2023091200005             0  0.011483       bias               bias
# ..             ...           ...       ...        ...                ...
# 430  2023091200430            20   20.2349    science             object
# 431  2023091200431            20   20.2428    science             object
# 432  2023091200432            20   20.2329    science             object
# 433  2023091200433             5   5.24483        acq                acq
# 434  2023091200434             5   5.23773        acq                acq
#
#        dayObs seqNum          Group id              Target Science program  \
# 1    20230912      1  2744773622920000       Park position         unknown
# 2    20230912      2  2744773677250000       Park position         unknown
# 3    20230912      3  2744785664300000  DaytimeCheckout001         unknown
# 4    20230912      4  2744787400740000  DaytimeCheckout002         unknown
# 5    20230912      5  2744831792910000  FlatField position         unknown
# ..        ...    ...               ...                 ...             ...
# 430  20230912    430  2745102492280000              HD2811     SITCOM-1001
# 431  20230912    431  2745102492280000              HD2811     SITCOM-1001
# 432  20230912    432  2745102492280000              HD2811     SITCOM-1001
# 433  20230912    433  2745109835900000            HD185975     SITCOM-1001
# 434  20230912    434  2745109835900000            HD185975     SITCOM-1001
#
#      ... Mount jitter RMS Mount motion image degradation  \
# 1    ...              NaN                            NaN
# 2    ...              NaN                            NaN
# 3    ...         0.032052                       0.029619
# 4    ...         0.043537                       0.009012
# 5    ...              NaN                            NaN
# ..   ...              ...                            ...
# 430  ...         0.180523                       0.130715
# 431  ...         0.191078                        0.09226
# 432  ...         0.231543                       0.102844
# 433  ...         0.112853                       0.112593
# 434  ...         0.086058                       0.085174
#
#     50-sigma source count _50-sigma source count  \
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
# 5                     NaN                    NaN
# ..                    ...                    ...
# 430                   NaN                    NaN
# 431                   NaN                    NaN
# 432                   NaN                    NaN
# 433                   NaN                    NaN
# 434                   NaN                    NaN
#
#     _Mount motion image degradation Log message Log level Jira ticket  \
# 1                               NaN         NaN       NaN         NaN
# 2                               NaN         NaN       NaN         NaN
# 3                               NaN         NaN       NaN         NaN
# 4                               NaN         NaN       NaN         NaN
# 5                               NaN         NaN       NaN         NaN
# ..                              ...         ...       ...         ...
# 430                             NaN         NaN       NaN         NaN
# 431                             NaN         NaN       NaN         NaN
# 432                             NaN         NaN       NaN         NaN
# 433                             NaN         NaN       NaN         NaN
# 434                             NaN         NaN       NaN         NaN
#
#     Quality flag Has annotations?
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# 5            NaN              NaN
# ..           ...              ...
# 430          NaN              NaN
# 431          NaN              NaN
# 432          NaN              NaN
# 433          NaN              NaN
# 434          NaN              NaN
#
# [434 rows x 32 columns]

# %%
df_in_transposed.columns
# Out:
# Index(['Exposure id', 'Exposure time', 'Darktime', 'Image type',
#        'Observation reason', 'dayObs', 'seqNum', 'Group id', 'Target',
#        'Science program', 'RA', 'Dec', 'Sky angle', 'Azimuth', 'Zenith angle',
#        'TAI', 'Filter', 'Disperser', 'Airmass', 'Focus-Z', 'Altitude',
#        'DIMM Seeing', 'Mount jitter RMS', 'Mount motion image degradation',
#        '50-sigma source count', '_50-sigma source count',
#        '_Mount motion image degradation', 'Log message', 'Log level',
#        'Jira ticket', 'Quality flag', 'Has annotations?'],
#       dtype='object')

# %%
df_in_transposed["Science program"].unique()
# Out:
# array(['unknown', 'CWFS', 'SITCOM-1009', 'BLOCK-91', 'SITCOM-1010',
#        'BLOCK-92', 'cwfs', 'SITCOM-1001'], dtype=object)

# %%
JIRA_EPIC = "SITCOM-1001"

# %%
selection = (df_in_transposed["Science program"] == JIRA_EPIC) & (df_in_transposed["Image type"] == "science")

# %%
df_in = df_in_transposed[selection]

# %%
df_in
# Out:
#        Exposure id Exposure time Darktime Image type Observation reason  \
# 247  2023091200247            30  30.2438    science             object
# 248  2023091200248            30  30.2388    science             object
# 249  2023091200249            30  30.2323    science             object
# 250  2023091200250            30  30.2366    science             object
# 251  2023091200251            30  30.2413    science             object
# ..             ...           ...      ...        ...                ...
# 428  2023091200428            20  20.2331    science             object
# 429  2023091200429            20  20.2471    science             object
# 430  2023091200430            20  20.2349    science             object
# 431  2023091200431            20  20.2428    science             object
# 432  2023091200432            20  20.2329    science             object
#
#        dayObs seqNum          Group id    Target Science program  ...  \
# 247  20230912    247  2745025530440000  HD167060     SITCOM-1001  ...
# 248  20230912    248  2745025530440000  HD167060     SITCOM-1001  ...
# 249  20230912    249  2745025530440000  HD167060     SITCOM-1001  ...
# 250  20230912    250  2745025530440000  HD167060     SITCOM-1001  ...
# 251  20230912    251  2745025530440000  HD167060     SITCOM-1001  ...
# ..        ...    ...               ...       ...             ...  ...
# 428  20230912    428  2745102492280000    HD2811     SITCOM-1001  ...
# 429  20230912    429  2745102492280000    HD2811     SITCOM-1001  ...
# 430  20230912    430  2745102492280000    HD2811     SITCOM-1001  ...
# 431  20230912    431  2745102492280000    HD2811     SITCOM-1001  ...
# 432  20230912    432  2745102492280000    HD2811     SITCOM-1001  ...
#
#     Mount jitter RMS Mount motion image degradation 50-sigma source count  \
# 247         0.810507                        0.58888                   NaN
# 248         0.690022                        0.48633                   NaN
# 249         0.362108                       0.267836                   NaN
# 250         0.280331                       0.220844                   NaN
# 251          0.11474                       0.092202                   NaN
# ..               ...                            ...                   ...
# 428          0.19517                       0.133185                   NaN
# 429          0.18814                       0.082596                   NaN
# 430         0.180523                       0.130715                   NaN
# 431         0.191078                        0.09226                   NaN
# 432         0.231543                       0.102844                   NaN
#
#     _50-sigma source count _Mount motion image degradation Log message  \
# 247                    NaN                             bad         NaN
# 248                    NaN                             bad         NaN
# 249                    NaN                         warning         NaN
# 250                    NaN                             NaN         NaN
# 251                    NaN                             NaN         NaN
# ..                     ...                             ...         ...
# 428                    NaN                             NaN         NaN
# 429                    NaN                             NaN         NaN
# 430                    NaN                             NaN         NaN
# 431                    NaN                             NaN         NaN
# 432                    NaN                             NaN         NaN
#
#     Log level Jira ticket Quality flag Has annotations?
# 247       NaN         NaN          NaN              NaN
# 248       NaN         NaN          NaN              NaN
# 249       NaN         NaN          NaN              NaN
# 250       NaN         NaN          NaN              NaN
# 251       NaN         NaN          NaN              NaN
# ..        ...         ...          ...              ...
# 428       NaN         NaN          NaN              NaN
# 429       NaN         NaN          NaN              NaN
# 430       NaN         NaN          NaN              NaN
# 431       NaN         NaN          NaN              NaN
# 432       NaN         NaN          NaN              NaN
#
# [144 rows x 32 columns]

# %%
df_in["Science program"].unique()
# Out:
# array(['SITCOM-1001'], dtype=object)

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num','time_start','time_end' ,'type', 'target','filter','zenith_angle','expos','ra','dec','skyangle','azimuth','zenith','science_program','jd','mjd'])

# %%
print(butler.registry.dimensions["exposure"].RecordClass.fields)
# Out:
# exposure:
#   instrument: str
#   id: int
#   physical_filter: str
#   obs_id: str
#   exposure_time: float
#   dark_time: float
#   observation_type: str
#   observation_reason: str
#   day_obs: int
#   seq_num: int
#   seq_start: int
#   seq_end: int
#   group_name: str
#   group_id: int
#   target_name: str
#   science_program: str
#   tracking_ra: float
#   tracking_dec: float
#   sky_angle: float
#   azimuth: float
#   zenith_angle: float
#   has_simulated: bool
#   timespan: lsst.daf.butler.Timespan

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure',where= "instrument='LATISS'")):
    
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num,pd.to_datetime(info.timespan.begin.to_string()),pd.to_datetime(info.timespan.end.to_string()) ,info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.exposure_time,info.tracking_ra, info.tracking_dec, info.sky_angle,info.azimuth ,info.zenith_angle, info.science_program,
                             info.timespan.begin.jd,info.timespan.begin.mjd ]
    
    if count < 5:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
        
        mjd = Time(info.timespan.begin.to_string()).mjd
        jd = Time(info.timespan.begin.to_string()).jd
        print(mjd,jd)
# Out:
# ----------------------------------------------------- 0 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2022083100004
#   physical_filter: 'unknown~unknown'
#   obs_id: 'AT_O_20220831_000004'
#   exposure_time: 0.0
#   dark_time: 0.0160482
#   observation_type: 'bias'
#   observation_reason: 'bias'
#   day_obs: 20220831
#   seq_num: 4
#   seq_start: 4
#   seq_end: 4
#   group_name: '2022083100004'
#   group_id: 2022083100004
#   target_name: 'UNKNOWN'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   azimuth: None
#   zenith_angle: None
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2022-08-31 22:58:13.633984', scale='tai', format='iso'), end=astropy.time.Time('2022-08-31 22:58:13.650000', scale='tai', format='iso'))
# 	 id:                   2022083100004
# 	 day_obs:              20220831
# 	 seq_num:              4
# 	 type-of-observation:  bias
# 	 target:               UNKNOWN
# 59822.957102245186 2459823.457102245
# ----------------------------------------------------- 1 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2022083100008
#   physical_filter: 'unknown~unknown'
#   obs_id: 'AT_O_20220831_000008'
#   exposure_time: 0.0
#   dark_time: 0.0111244
#   observation_type: 'bias'
#   observation_reason: 'bias'
#   day_obs: 20220831
#   seq_num: 8
#   seq_start: 8
#   seq_end: 8
#   group_name: '2022083100008'
#   group_id: 2022083100008
#   target_name: 'UNKNOWN'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   azimuth: None
#   zenith_angle: None
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2022-08-31 22:59:16.387013', scale='tai', format='iso'), end=astropy.time.Time('2022-08-31 22:59:16.398000', scale='tai', format='iso'))
# 	 id:                   2022083100008
# 	 day_obs:              20220831
# 	 seq_num:              8
# 	 type-of-observation:  bias
# 	 target:               UNKNOWN
# 59822.95782855339 2459823.4578285534
# ----------------------------------------------------- 2 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2022083100007
#   physical_filter: 'unknown~unknown'
#   obs_id: 'AT_O_20220831_000007'
#   exposure_time: 0.0
#   dark_time: 0.0119367
#   observation_type: 'bias'
#   observation_reason: 'bias'
#   day_obs: 20220831
#   seq_num: 7
#   seq_start: 7
#   seq_end: 7
#   group_name: '2022083100007'
#   group_id: 2022083100007
#   target_name: 'UNKNOWN'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   azimuth: None
#   zenith_angle: None
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2022-08-31 22:59:11.978990', scale='tai', format='iso'), end=astropy.time.Time('2022-08-31 22:59:11.991000', scale='tai', format='iso'))
# 	 id:                   2022083100007
# 	 day_obs:              20220831
# 	 seq_num:              7
# 	 type-of-observation:  bias
# 	 target:               UNKNOWN
# 59822.957777534604 2459823.4577775346
# ----------------------------------------------------- 3 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2022083100009
#   physical_filter: 'unknown~unknown'
#   obs_id: 'AT_O_20220831_000009'
#   exposure_time: 0.0
#   dark_time: 0.0105329
#   observation_type: 'bias'
#   observation_reason: 'bias'
#   day_obs: 20220831
#   seq_num: 9
#   seq_start: 9
#   seq_end: 9
#   group_name: '2022083100009'
#   group_id: 2022083100009
#   target_name: 'UNKNOWN'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   azimuth: None
#   zenith_angle: None
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2022-08-31 22:59:20.801996', scale='tai', format='iso'), end=astropy.time.Time('2022-08-31 22:59:20.813000', scale='tai', format='iso'))
# 	 id:                   2022083100009
# 	 day_obs:              20220831
# 	 seq_num:              9
# 	 type-of-observation:  bias
# 	 target:               UNKNOWN
# 59822.957879652735 2459823.4578796527
# ----------------------------------------------------- 4 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2022083100012
#   physical_filter: 'unknown~unknown'
#   obs_id: 'AT_O_20220831_000012'
#   exposure_time: 3.0
#   dark_time: 3.01067
#   observation_type: 'dark'
#   observation_reason: 'dark'
#   day_obs: 20220831
#   seq_num: 12
#   seq_start: 12
#   seq_end: 12
#   group_name: '2022083100012'
#   group_id: 2022083100012
#   target_name: 'UNKNOWN'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   azimuth: None
#   zenith_angle: None
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2022-08-31 23:00:00.113994', scale='tai', format='iso'), end=astropy.time.Time('2022-08-31 23:00:03.124000', scale='tai', format='iso'))
# 	 id:                   2022083100012
# 	 day_obs:              20220831
# 	 seq_num:              12
# 	 type-of-observation:  dark
# 	 target:               UNKNOWN
# 59822.95833465271 2459823.4583346527

# %%
info.toDict()
# Out:
# {'instrument': 'LATISS',
#  'id': 2023091200434,
#  'physical_filter': 'empty~holo4_003',
#  'obs_id': 'AT_O_20230912_000434',
#  'exposure_time': 5.0,
#  'dark_time': 5.23773,
#  'observation_type': 'acq',
#  'observation_reason': 'acq',
#  'day_obs': 20230912,
#  'seq_num': 434,
#  'seq_start': 434,
#  'seq_end': 434,
#  'group_name': '2023-09-13T05:03:03.590',
#  'group_id': 2745109835900000,
#  'target_name': 'HD185975',
#  'science_program': 'SITCOM-1001',
#  'tracking_ra': 307.7266654147103,
#  'tracking_dec': -87.50524198429619,
#  'sky_angle': 140.88383982965203,
#  'azimuth': 182.2050468857024,
#  'zenith_angle': 57.988535284698564,
#  'has_simulated': False,
#  'timespan': Timespan(begin=astropy.time.Time('2023-09-13 05:04:17.004011', scale='tai', format='iso'), end=astropy.time.Time('2023-09-13 05:04:22.242000', scale='tai', format='iso'))}

# %%
info
# Out:
# exposure.RecordClass(instrument='LATISS', id=2023091200434, physical_filter='empty~holo4_003', obs_id='AT_O_20230912_000434', exposure_time=5.0, dark_time=5.23773, observation_type='acq', observation_reason='acq', day_obs=20230912, seq_num=434, seq_start=434, seq_end=434, group_name='2023-09-13T05:03:03.590', group_id=2745109835900000, target_name='HD185975', science_program='SITCOM-1001', tracking_ra=307.7266654147103, tracking_dec=-87.50524198429619, sky_angle=140.88383982965203, azimuth=182.2050468857024, zenith_angle=57.988535284698564, has_simulated=False, timespan=Timespan(begin=astropy.time.Time('2023-09-13 05:04:17.004011', scale='tai', format='iso'), end=astropy.time.Time('2023-09-13 05:04:22.242000', scale='tai', format='iso')))

# %%
info.azimuth
# Out:
# 182.2050468857024

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num  \
# 0      2022083100004  AT_O_20220831_000004  20220831        4
# 1      2022083100008  AT_O_20220831_000008  20220831        8
# 2      2022083100007  AT_O_20220831_000007  20220831        7
# 3      2022083100009  AT_O_20220831_000009  20220831        9
# 4      2022083100012  AT_O_20220831_000012  20220831       12
# ...              ...                   ...       ...      ...
# 57772  2023091200422  AT_O_20230912_000422  20230912      422
# 57773  2023091200425  AT_O_20230912_000425  20230912      425
# 57774  2023091200428  AT_O_20230912_000428  20230912      428
# 57775  2023091200431  AT_O_20230912_000431  20230912      431
# 57776  2023091200434  AT_O_20230912_000434  20230912      434
#
#                       time_start                time_end     type    target  \
# 0     2022-08-31 22:58:13.633984 2022-08-31 22:58:13.650     bias   UNKNOWN
# 1     2022-08-31 22:59:16.387013 2022-08-31 22:59:16.398     bias   UNKNOWN
# 2     2022-08-31 22:59:11.978990 2022-08-31 22:59:11.991     bias   UNKNOWN
# 3     2022-08-31 22:59:20.801996 2022-08-31 22:59:20.813     bias   UNKNOWN
# 4     2022-08-31 23:00:00.113994 2022-08-31 23:00:03.124     dark   UNKNOWN
# ...                          ...                     ...      ...       ...
# 57772 2023-09-13 04:55:58.170989 2023-09-13 04:56:28.413  science    HD2811
# 57773 2023-09-13 04:58:10.659991 2023-09-13 04:58:40.907  science    HD2811
# 57774 2023-09-13 05:00:16.964999 2023-09-13 05:00:37.198  science    HD2811
# 57775 2023-09-13 05:01:57.725989 2023-09-13 05:02:17.969  science    HD2811
# 57776 2023-09-13 05:04:17.004011 2023-09-13 05:04:22.242      acq  HD185975
#
#                            filter  zenith_angle  expos          ra        dec  \
# 0                 unknown~unknown           NaN    0.0         NaN        NaN
# 1                 unknown~unknown           NaN    0.0         NaN        NaN
# 2                 unknown~unknown           NaN    0.0         NaN        NaN
# 3                 unknown~unknown           NaN    0.0         NaN        NaN
# 4                 unknown~unknown           NaN    3.0         NaN        NaN
# ...                           ...           ...    ...         ...        ...
# 57772             empty~holo4_001     16.835979   30.0    7.874724 -43.578432
# 57773        collimator~holo4_003     16.567957   30.0    7.874850 -43.578505
# 57774  collimator~blue300lpmm_qn1     16.316714   20.0    7.874720 -43.578408
# 57775       empty~blue300lpmm_qn1     16.123981   20.0    7.874755 -43.578430
# 57776             empty~holo4_003     57.988535    5.0  307.726665 -87.505242
#
#          skyangle     azimuth     zenith science_program            jd  \
# 0             NaN         NaN        NaN         unknown  2.459823e+06
# 1             NaN         NaN        NaN         unknown  2.459823e+06
# 2             NaN         NaN        NaN         unknown  2.459823e+06
# 3             NaN         NaN        NaN         unknown  2.459823e+06
# 4             NaN         NaN        NaN         unknown  2.459823e+06
# ...           ...         ...        ...             ...           ...
# 57772   46.235854  145.227081  16.835979     SITCOM-1001  2.460201e+06
# 57773   46.235648  146.261365  16.567957     SITCOM-1001  2.460201e+06
# 57774   46.235811  147.293217  16.316714     SITCOM-1001  2.460201e+06
# 57775   46.235692  148.131393  16.123981     SITCOM-1001  2.460201e+06
# 57776  140.883840  182.205047  57.988535     SITCOM-1001  2.460201e+06
#
#                 mjd
# 0      59822.957102
# 1      59822.957829
# 2      59822.957778
# 3      59822.957880
# 4      59822.958335
# ...             ...
# 57772  60200.205534
# 57773  60200.207068
# 57774  60200.208530
# 57775  60200.209696
# 57776  60200.211308
#
# [57777 rows x 19 columns]

# %%
df_exposure = df_exposure.astype({"id": int,'day_obs': int,'seq_num':int})

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num  \
# 0      2022083100004  AT_O_20220831_000004  20220831        4
# 1      2022083100008  AT_O_20220831_000008  20220831        8
# 2      2022083100007  AT_O_20220831_000007  20220831        7
# 3      2022083100009  AT_O_20220831_000009  20220831        9
# 4      2022083100012  AT_O_20220831_000012  20220831       12
# ...              ...                   ...       ...      ...
# 57772  2023091200422  AT_O_20230912_000422  20230912      422
# 57773  2023091200425  AT_O_20230912_000425  20230912      425
# 57774  2023091200428  AT_O_20230912_000428  20230912      428
# 57775  2023091200431  AT_O_20230912_000431  20230912      431
# 57776  2023091200434  AT_O_20230912_000434  20230912      434
#
#                       time_start                time_end     type    target  \
# 0     2022-08-31 22:58:13.633984 2022-08-31 22:58:13.650     bias   UNKNOWN
# 1     2022-08-31 22:59:16.387013 2022-08-31 22:59:16.398     bias   UNKNOWN
# 2     2022-08-31 22:59:11.978990 2022-08-31 22:59:11.991     bias   UNKNOWN
# 3     2022-08-31 22:59:20.801996 2022-08-31 22:59:20.813     bias   UNKNOWN
# 4     2022-08-31 23:00:00.113994 2022-08-31 23:00:03.124     dark   UNKNOWN
# ...                          ...                     ...      ...       ...
# 57772 2023-09-13 04:55:58.170989 2023-09-13 04:56:28.413  science    HD2811
# 57773 2023-09-13 04:58:10.659991 2023-09-13 04:58:40.907  science    HD2811
# 57774 2023-09-13 05:00:16.964999 2023-09-13 05:00:37.198  science    HD2811
# 57775 2023-09-13 05:01:57.725989 2023-09-13 05:02:17.969  science    HD2811
# 57776 2023-09-13 05:04:17.004011 2023-09-13 05:04:22.242      acq  HD185975
#
#                            filter  zenith_angle  expos          ra        dec  \
# 0                 unknown~unknown           NaN    0.0         NaN        NaN
# 1                 unknown~unknown           NaN    0.0         NaN        NaN
# 2                 unknown~unknown           NaN    0.0         NaN        NaN
# 3                 unknown~unknown           NaN    0.0         NaN        NaN
# 4                 unknown~unknown           NaN    3.0         NaN        NaN
# ...                           ...           ...    ...         ...        ...
# 57772             empty~holo4_001     16.835979   30.0    7.874724 -43.578432
# 57773        collimator~holo4_003     16.567957   30.0    7.874850 -43.578505
# 57774  collimator~blue300lpmm_qn1     16.316714   20.0    7.874720 -43.578408
# 57775       empty~blue300lpmm_qn1     16.123981   20.0    7.874755 -43.578430
# 57776             empty~holo4_003     57.988535    5.0  307.726665 -87.505242
#
#          skyangle     azimuth     zenith science_program            jd  \
# 0             NaN         NaN        NaN         unknown  2.459823e+06
# 1             NaN         NaN        NaN         unknown  2.459823e+06
# 2             NaN         NaN        NaN         unknown  2.459823e+06
# 3             NaN         NaN        NaN         unknown  2.459823e+06
# 4             NaN         NaN        NaN         unknown  2.459823e+06
# ...           ...         ...        ...             ...           ...
# 57772   46.235854  145.227081  16.835979     SITCOM-1001  2.460201e+06
# 57773   46.235648  146.261365  16.567957     SITCOM-1001  2.460201e+06
# 57774   46.235811  147.293217  16.316714     SITCOM-1001  2.460201e+06
# 57775   46.235692  148.131393  16.123981     SITCOM-1001  2.460201e+06
# 57776  140.883840  182.205047  57.988535     SITCOM-1001  2.460201e+06
#
#                 mjd
# 0      59822.957102
# 1      59822.957829
# 2      59822.957778
# 3      59822.957880
# 4      59822.958335
# ...             ...
# 57772  60200.205534
# 57773  60200.207068
# 57774  60200.208530
# 57775  60200.209696
# 57776  60200.211308
#
# [57777 rows x 19 columns]

# %% [markdown]
# ## Selection of science

# %%
df_science = df_exposure[df_exposure.type == 'science']

# %%
df_science.sort_values(by="id",ascending=True,inplace=True)

# %%
df_science.tail(60)

# %%
df_science.day_obs.unique()

# %% [markdown]
# ## Selection of date

# %% [markdown]
# 2021-02-16  2021-02-18  2021-06-08  2021-06-10  2021-07-07  2021-09-07  2021-09-09  2021-10-06  2021-11-02  2021-11-04  2022-02-16  2022-03-15  2022-03-17  20220502
# 2021-02-17  2021-03-11  2021-06-09  2021-07-06  2021-07-08  2021-09-08  2021-10-05  2021-10-07  2021-11-03  2022-02-15  2022-02-17  2022-03-16  2022-03-18  20220503 20220524 20220607 20220608 20220609

# %% [markdown]
# ### Add those
#
# 20220504 - Not existing

# %%
#date_sel = 20220630
#date_sel = 20220630
#date_sel = 20221208
#date_sel = 20221209

# data in january
#date_sel= 20230118
#date_sel= 20230131

# data in February
#date_sel = 20230201
#date_sel = 20230202
#date_sel = 20230704

#date_sel = 20230510
#date_sel = 20230509
#date_sel = 20230511

#date_sel = 20230705
#date_sel = 20230706

#july 2023
#date_sel = 20230718
#date_sel = 20230720

#august 2023
#date_sel = 20230801
#date_sel = 20230802

#date_sel = 20230815
#date_sel = 20230817

#september 2023
date_sel = 20230912

# %% [markdown]
# ## Query Dimension records on Exposures

# %%
where_clause = f"instrument=\'LATISS\' AND exposure.day_obs={date_sel} AND exposure.science_program=\'spec\'"

# %%
results_exposures = registry.queryDimensionRecords('exposure',datasets="raw",collections = 'LATISS/raw/all',where=where_clause)

# %% [markdown]
# ## Select date

# %%
df_science_selected = df_science[df_science.day_obs == date_sel ]

# %%
len(df_science_selected)

# %% [markdown]
# # List of filters

# %%
list_of_filters = df_science_selected['filter'].unique()
list_of_filters

# %%
selected_filters = []
for filt in list_of_filters:
    #flag_sel = (filt.find('holo4') != -1) or (filt.find('ronchi90lpmm') != -1) or (filt.find('ronchi170lpmm') != -1)
    flag_sel = (filt.find('holo4') != -1) 
    #flag_sel = (filt.find('ronchi170') != -1) 
    if flag_sel:
        selected_filters.append(filt) 
selected_filters = np.array(selected_filters)
selected_filters

# %% [markdown]
# ## Selection of filter
#
# - But now we have a loop on filters

# %%
#idx_sel_filt = 0
#selected_filter = selected_filters[0]
#selected_filter

# %% [markdown]
# ## Final selection of exposure
#
# - loop on selected filters

# %%
pd.set_option('display.max_rows', None)

# %%
all_def_science_selected_final = []

for selected_filter in selected_filters:

    print(selected_filter)
    df_science_selected_final = df_science_selected[df_science_selected["filter"] ==  selected_filter]
    
    #print(df_science_selected_final)
    all_def_science_selected_final.append(df_science_selected_final.copy())
    
    df = df_science_selected_final
    df_sel = df[['day_obs', 'seq_num']]
    
    
    NN = len(df)
    
    if NN>0:
        # build the line
        
        df_sel['line'] = df_sel.apply(lambda row: str(row['day_obs'])  + " " + str(row['seq_num']),axis = 1)
    
    
         # prepare output
        filename_out = "visitdispersers_"+ str(date_sel) + "_filt_" + selected_filter.replace('~','-') + ".list"
        print(filename_out)
        
        df_out = df_sel[["line"]]
        df_out.to_csv(filename_out, index=False, header=None)

# %%
N = len(all_def_science_selected_final)

# %%
if N>=1:
    n0=len(all_def_science_selected_final[0])
    display(all_def_science_selected_final[0])

# %%
if N>=2:
    n1=len(all_def_science_selected_final[1])
    display(all_def_science_selected_final[1])

# %%
if N>=3:
    n2=len(all_def_science_selected_final[2])
    display(all_def_science_selected_final[2])

# %%
if N>=4:
    n3=len(all_def_science_selected_final[3])
    display(all_def_science_selected_final[3])

# %%
if N>=5:
    n4=len(all_def_science_selected_final[4])
    display(all_def_science_selected_final[4])

# %%
df_forsave = pd.concat(all_def_science_selected_final)

# %%
filename_out_csv = "holosummary_"+ str(date_sel) + ".csv"
filename_out_excel = "holosummary_"+ str(date_sel) + ".xlsx"

# %%
filename_out_csv

# %%
df_forsave.to_csv(filename_out_csv)

# %%
! pip install openpyxl

# %%
df_forsave.to_excel(filename_out_excel)
