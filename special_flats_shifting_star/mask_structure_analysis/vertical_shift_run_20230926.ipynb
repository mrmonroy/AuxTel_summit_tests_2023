# %%
import os
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import matplotlib.dates as mdates

import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.visualization import (MinMaxInterval, SqrtStretch,ZScaleInterval,PercentileInterval,
                                   ImageNormalize,imshow_norm)
from astropy.visualization.stretch import SinhStretch, LinearStretch,AsinhStretch,LogStretch


from astropy.io import fits

# %%
# Assembly task
# https://github.com/lsst/ip_isr/blob/main/python/lsst/ip/isr/isrTask.py

from lsst.ip.isr.assembleCcdTask import (AssembleCcdConfig, AssembleCcdTask)
from lsst.ip.isr.isrTask import (IsrTask, IsrTaskConfig)

#https://github.com/lsst/ip_isr/blob/main/python/lsst/ip/isr/overscan.py
from lsst.ip.isr import  OverscanCorrectionTaskConfig, OverscanCorrectionTask

# %%
# LSST Display
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
! eups list -s
# Out:
# afw                   gb62437fd66+a272651890 	current w_2023_39 setup
# alert_packet          g6041bd2d66 	current w_2023_39 setup
# analysis_drp          g8a53795882+852a24a654 	current w_2023_39 setup
# analysis_tools        g92b6ad8a5b+40272a923a 	current w_2023_39 setup
# ap_association        g6a6fcd37b7+f5af200bc5 	current w_2023_39 setup
# ap_pipe               g9f065385ad+090559a986 	current w_2023_39 setup
# ap_verify             g60239a501b+ad285bcdbf 	current w_2023_39 setup
# astro_metadata_translator g0978aabd1f+0ffa813159 	current w_2023_39 setup
# astshim               g3273194fdb+f6908454ef 	current w_2023_39 setup
# atmospec              LOCAL:/home/m/monroy/repos/repos_w_2023_35/atmospec 	setup
# base                  g98ffbb4407+81bc2a20b4 	current w_2023_39 setup
# cbp                   ga32fcf49c8+1b73362753 	current w_2023_39 setup
# cell_coadds           g9faf7ed3f3+852a24a654 	current w_2023_39 setup
# coadd_utils           g337abbeb29+1b73362753 	current w_2023_39 setup
# cp_pipe               g857a3418e4+852a24a654 	current w_2023_39 setup
# cp_verify             ge14ceffff4+40272a923a 	current w_2023_39 setup
# cpputils              g9ddcbc5298+7f7571301f 	current w_2023_39 setup
# ctrl_bps              g1510ddf336+a66ba965ef 	current w_2023_39 setup
# ctrl_bps_htcondor     ga0efba6fd5+4658ea33b5 	current w_2023_39 setup
# ctrl_bps_panda        g84a8fe0248+4658ea33b5 	current w_2023_39 setup
# ctrl_bps_parsl        g0782abdf86+4658ea33b5 	current w_2023_39 setup
# ctrl_execute          g3288a415c1+c96752b144 	current w_2023_39 setup
# ctrl_mpexec           g8e0072ff9e+5feaf3aa47 	current w_2023_39 setup
# ctrl_platform_s3df    g3be6bbf6ee+61fcefe6a9 	current w_2023_39 setup
# daf_base              gf041782ebf+1e6588183a 	current w_2023_39 setup
# daf_butler            gfbd223d45b+f49700b132 	current w_2023_39 setup
# daf_relation          g7fe878355c+6c74b93b31 	current w_2023_39 setup
# dax_apdb              g4122c88930+bfeb42fd3c 	current w_2023_39 setup
# display_astrowidgets  g2bbee38e9b+1b73362753 	current w_2023_39 setup
# display_ds9           gdb4ec4c597+1b73362753 	current w_2023_39 setup
# display_firefly       gae46bcf261+1b73362753 	current w_2023_39 setup
# display_matplotlib    g0265f82a02+1b73362753 	current w_2023_39 setup
# drp_pipe              g23615f0d05+1bd9d649de 	current w_2023_39 setup
# drp_tasks             g970b4cef05+db09143565 	current w_2023_39 setup
# dustmaps_cachedata    gbb0a0c949e+81bc2a20b4 	current w_2023_39 setup
# eups                  LOCAL:/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/eups 	setup
# faro                  ge8614a52ae+b811788ebf 	current w_2023_39 setup
# felis                 g5a39ba60c6+81bc2a20b4 	current w_2023_39 setup
# fgcm                  g0e55f264b1 	current w_2023_39 setup
# fgcmcal               g2ab4ef6978+ccef7de041 	current w_2023_39 setup
# gbdes                 gaa71a13f5d 	current w_2023_39 setup
# geom                  ga1e77700b3+951263b14e 	current w_2023_39 setup
# ip_diffim             gaca53a8f8a+1e963276af 	current w_2023_39 setup
# ip_isr                gba5f90d8bc+f67806a0a9 	current w_2023_39 setup
# jointcal              g4500d70958+ea842469ef 	current w_2023_39 setup
# jointcal_cholmod      g81a980c3dd+81bc2a20b4 	current w_2023_39 setup
# kht                   gafcb7142de 	current w_2023_39 setup
# log                   g1e7d6db67d+6c74b93b31 	current w_2023_39 setup
# lsst_apps             ga3d9597cd8+91d5b08c18 	current w_2023_39 setup
# lsst_bps_plugins      g3a590c521e+e8d22408bb 	current w_2023_39 setup
# lsst_distrib          g4213664e8e+60ff72a28d 	current w_2023_39 setup
# lsst_obs              gea673b7ed9+80db6ff7df 	current w_2023_39 setup
# lsst_sitcom           g1a510c377c+163efc29fb 	current w_2023_39 setup
# meas_algorithms       g728939a55c+71a2f45ad6 	current w_2023_39 setup
# meas_astrom           g0d499ea81f+f67806a0a9 	current w_2023_39 setup
# meas_base             g4fadbfc174+69dba87494 	current w_2023_39 setup
# meas_deblender        gb700894bec+f0e28b3f74 	current w_2023_39 setup
# meas_extensions_convolved g42fff21dfb+29370e3b1a 	current w_2023_39 setup
# meas_extensions_gaap  g8dd6597355+3a62fbdd20 	current w_2023_39 setup
# meas_extensions_photometryKron gb2715bf1a1+f67806a0a9 	current w_2023_39 setup
# meas_extensions_piff  gc86a011abf+f67806a0a9 	current w_2023_39 setup
# meas_extensions_psfex gbeb006f7da+1a7b092fa4 	current w_2023_39 setup
# meas_extensions_scarlet g69cd701f67+9315116a74 	current w_2023_39 setup
# meas_extensions_shapeHSM g571dde35ae+f67806a0a9 	current w_2023_39 setup
# meas_extensions_simpleShape gcf0d15dbbd+71a2f45ad6 	current w_2023_39 setup
# meas_extensions_trailedSources g47da3c6c86+71a2f45ad6 	current w_2023_39 setup
# meas_modelfit         gd162630629+fafaf7382a 	current w_2023_39 setup
# meas_transiNet        gdb5f421a5e+71a2f45ad6 	current w_2023_39 setup
# obs_base              g0720eaffcd+f26066d43f 	current w_2023_39 setup
# obs_cfht              gef70c04d3b+f1af2eb53a 	current w_2023_39 setup
# obs_decam             g8fee9bba00+5e5e039e83 	current w_2023_39 setup
# obs_decam_data        g9eeeb5e174 	current w_2023_39 setup
# obs_lsst              gcadcf6406f+5a55f2407f 	current w_2023_39 setup
# obs_lsst_data         g5736ae6652 	current w_2023_39 setup
# obs_subaru            g7b00f9367a+89380900a1 	current w_2023_39 setup
# obs_subaru_data       g7ff78db354 	current w_2023_39 setup
# pex_config            g41b076d227+0ffa813159 	current w_2023_39 setup
# pex_exceptions        gdaeeff99f8+0d8dbea60f 	current w_2023_39 setup
# pipe_base             g76003a3ac4+c9c09ef569 	current w_2023_39 setup
# pipe_tasks            gaec7515425+d966937eae 	current w_2023_39 setup
# proxmin               g33b4157f25 	current w_2023_39 setup
# psfex                 gc054bea089+81bc2a20b4 	current w_2023_39 setup
# resources             g8c7666fb0b+6c74b93b31 	current w_2023_39 setup
# scarlet               g63ff1f842d+4083830bf8 	current w_2023_39 setup
# scarlet_extensions    g9d18589735+d445b4966c 	current w_2023_39 setup
# sconsUtils            g80c3e6a29f 	current w_2023_39 setup
# sdm_schemas           g68d4b446e6 	current w_2023_39 setup
# shapelet              g44018dc512+1b73362753 	current w_2023_39 setup
# skymap                g93973518b8+4dc41abcde 	current w_2023_39 setup
# spectractor           LOCAL:/home/m/monroy/repos/repos_w_2023_35/Spectractor 	setup
# sphgeom               g6ae5381d9b+81bc2a20b4 	current w_2023_39 setup
# summit_extras         g57c6b4248f+14d5731ea1 	current w_2023_39 setup
# summit_utils          g10219f4517+678014b853 	current w_2023_39 setup
# utils                 g384e8880d6+81bc2a20b4 	current w_2023_39 setup
# verify                gffb8816710+223aa9fa34 	current w_2023_39 setup
# verify_metrics        g3c17f34f15+81bc2a20b4 	current w_2023_39 setup

# %% [markdown]
# # Butler

# %%
import lsst.daf.butler as dafButler

# %%
embargo = True

# %%
if embargo:
    repo="/sdf/group/rubin/repo/oga/"
else:
    repo = "/sdf/group/rubin/repo/main"
butler = dafButler.Butler(repo)
registry = butler.registry

# %%
cameraName = 'LATISS'
calibCollections = ['LATISS/defaults','LATISS/raw/all']
for col in registry.queryCollections("*LATISS/calib*"):
    #print(col)
    calibCollections.append(col)

# %% [markdown]
# # Paths

# %%
outdir_base = 'output_fits/'
if os.path.exists(outdir_base)==False:
    os.mkdir(outdir_base)
outdir_label = 'vertical_shift_{0}/'

# %% [markdown]
# We check the different dimension records existing for *physical_filter*:

# %%
phys_filters = list(registry.queryDimensionRecords('physical_filter',where="instrument='LATISS'"))

# %% [markdown]
# Print physical_filters with hologram in place:

# %%
for f_ in phys_filters:
    if 'holo' in f_.name:
        print(f_.name)
# Out:
# empty~holo4_003
# blank_bk7_wg05~holo4_003
# KPNO_1111_436nm~holo4_003
# KPNO_373A_677nm~holo4_003
# KPNO_406_828nm~holo4_003
# unknown~holo4_003
# BG40~holo4_003
# quadnotch1~holo4_003
# RG610~holo4_003
# FELH0600~holo4_003
# SDSSg~holo4_003
# SDSSr~holo4_003
# SDSSi~holo4_003
# BG40_65mm_1~holo4_003
# BG40_65mm_2~holo4_003
# OG550_65mm_1~holo4_003
# OG550_65mm_2~holo4_003
# SDSSg_65mm~holo4_003
# SDSSr_65mm~holo4_003
# SDSSi_65mm~holo4_003
# SDSSu_65mm~holo4_003
# SDSSz_65mm~holo4_003
# SDSSy_65mm~holo4_003
# empty~holo4_001
# blank_bk7_wg05~holo4_001
# KPNO_1111_436nm~holo4_001
# KPNO_373A_677nm~holo4_001
# KPNO_406_828nm~holo4_001
# unknown~holo4_001
# BG40~holo4_001
# BG40_65mm_1~holo4_001
# BG40_65mm_2~holo4_001
# quadnotch1~holo4_001
# RG610~holo4_001
# OG550_65mm_1~holo4_001
# OG550_65mm_2~holo4_001
# FELH0600~holo4_001
# SDSSg~holo4_001
# SDSSr~holo4_001
# SDSSi~holo4_001
# SDSSu_65mm~holo4_001
# SDSSg_65mm~holo4_001
# SDSSr_65mm~holo4_001
# SDSSi_65mm~holo4_001
# SDSSz_65mm~holo4_001
# SDSSy_65mm~holo4_001
# collimator~holo4_003
# collimator~holo4_001
# cyl_lens~holo4_003
# cyl_lens~holo4_001

# %%
obs_type = 'science'
obs_day = 20230926
physical_filter = 'empty~holo4_003' #Note that there are no exposure with this config for the moment

# %%
df_science = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num','time_start',
                                    'time_end' ,'type', 'target','filter_disp','zenith_angle',
                                    'exp_time','ra','dec','skyangle','science_program'])

# %%
where_exps = "instrument='LATISS' AND exposure.observation_type='{0}' AND exposure.day_obs={1} AND physical_filter='{2}'".format(obs_type,obs_day,physical_filter)
#where_exps = "instrument='LATISS' AND exposure.observation_type='{0}' AND exposure.day_obs={1}".format(obs_type,obs_day)
for i, info in enumerate(registry.queryDimensionRecords('exposure',where=where_exps)):
    
    #if info.observation_type=='science':
    id_ = info.id
    obs_id_ = info.obs_id
    day_obs_ = info.day_obs
    seq_num_ = info.seq_num
    timespan_ = info.timespan
    timespan_begin_ = pd.to_datetime(timespan_.begin.to_string())
    timespan_end_ = pd.to_datetime(timespan_.end.to_string())
    timespan_begin_jd_ = timespan_.begin.jd
    timespan_begin_mjd_ = timespan_.begin.mjd

    observation_type_ = info.observation_type
    target_name_ = info.target_name
    physical_filter_ = info.physical_filter
    zenith_angle_ = info.zenith_angle
    exposure_time_ = info.exposure_time
    tracking_ra_ = info.tracking_ra
    tracking_dec_ = info.tracking_dec
    sky_angle_ = info.sky_angle
    science_program_ = info.science_program

    df_science.loc[i] = [id_, obs_id_, day_obs_, seq_num_,timespan_begin_,timespan_end_ ,observation_type_, \
                         target_name_, physical_filter_, zenith_angle_, exposure_time_,tracking_ra_, \
                         tracking_dec_, sky_angle_, science_program_]

    if i < 2:
        print(i)
        print(info)
        print("\t timespan:            ",info.timespan)
        print("\t timespan.begin:      ",info.timespan.begin)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
        print("-----------------------------------------------------")
# Out:
# 0
# exposure:
#   instrument: 'LATISS'
#   id: 2023092600446
#   physical_filter: 'empty~holo4_003'
#   obs_id: 'AT_O_20230926_000446'
#   exposure_time: 30.0
#   dark_time: 30.2346
#   observation_type: 'science'
#   observation_reason: 'sitcom-1043'
#   day_obs: 20230926
#   seq_num: 446
#   seq_start: 446
#   seq_end: 446
#   group_name: '2023-09-27T02:51:35.414'
#   group_id: 2757126954140000
#   target_name: 'HD2811'
#   science_program: 'BLOCK-102'
#   tracking_ra: 7.827800206545046
#   tracking_dec: -43.60460268648411
#   sky_angle: 19.097270869928906
#   azimuth: 127.53812441035177
#   zenith_angle: 27.05391872351369
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2023-09-27 02:54:18.911003', scale='tai', format='iso'), end=astropy.time.Time('2023-09-27 02:54:49.146000', scale='tai', format='iso'))
# 	 timespan:             [2023-09-27T02:54:18.911003, 2023-09-27T02:54:49.146000)
# 	 timespan.begin:       2023-09-27 02:54:18.911003
# 	 id:                   2023092600446
# 	 day_obs:              20230926
# 	 seq_num:              446
# 	 type-of-observation:  science
# 	 target:               HD2811
# -----------------------------------------------------
# 1
# exposure:
#   instrument: 'LATISS'
#   id: 2023092600447
#   physical_filter: 'empty~holo4_003'
#   obs_id: 'AT_O_20230926_000447'
#   exposure_time: 30.0
#   dark_time: 30.232
#   observation_type: 'science'
#   observation_reason: 'sitcom-1043'
#   day_obs: 20230926
#   seq_num: 447
#   seq_start: 447
#   seq_end: 447
#   group_name: '2023-09-27T02:51:35.414'
#   group_id: 2757126954140000
#   target_name: 'HD2811'
#   science_program: 'BLOCK-102'
#   tracking_ra: 7.827858567612268
#   tracking_dec: -43.60462363002238
#   sky_angle: 19.097272024363082
#   azimuth: 127.63345015305359
#   zenith_angle: 26.931007102071618
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2023-09-27 02:55:01.890010', scale='tai', format='iso'), end=astropy.time.Time('2023-09-27 02:55:32.122000', scale='tai', format='iso'))
# 	 timespan:             [2023-09-27T02:55:01.890010, 2023-09-27T02:55:32.122000)
# 	 timespan.begin:       2023-09-27 02:55:01.890010
# 	 id:                   2023092600447
# 	 day_obs:              20230926
# 	 seq_num:              447
# 	 type-of-observation:  science
# 	 target:               HD2811
# -----------------------------------------------------

# %%
print('Number of entries = ',len(df_science))
# Out:
# Number of entries =  70

# %%
df_science.tail(5)
# Out:
#                id                obs_id   day_obs  seq_num  \
# 65  2023092600514  AT_O_20230926_000514  20230926      514
# 66  2023092600515  AT_O_20230926_000515  20230926      515
# 67  2023092600516  AT_O_20230926_000516  20230926      516
# 68  2023092600546  AT_O_20230926_000546  20230926      546
# 69  2023092600547  AT_O_20230926_000547  20230926      547
#
#                    time_start                time_end     type    target  \
# 65 2023-09-27 03:43:44.508999 2023-09-27 03:43:54.753  science    HD2811
# 66 2023-09-27 03:44:18.201997 2023-09-27 03:44:28.438  science    HD2811
# 67 2023-09-27 03:44:41.214988 2023-09-27 03:44:51.445  science    HD2811
# 68 2023-09-27 04:26:20.017005 2023-09-27 04:27:20.264  science  HD009051
# 69 2023-09-27 04:27:33.071004 2023-09-27 04:28:33.325  science  HD009051
#
#         filter_disp  zenith_angle  exp_time         ra        dec    skyangle  \
# 65  empty~holo4_003     19.133679      10.0   7.830462 -43.602179   31.841334
# 66  empty~holo4_003     19.054660      10.0   7.831341 -43.600949   31.841343
# 67  empty~holo4_003     18.999954      10.0   7.831390 -43.600935   31.841309
# 68  empty~holo4_003     19.663878      60.0  22.194782 -24.339810  338.039960
# 69  empty~holo4_003     19.406802      60.0  22.194474 -24.339927  338.039789
#
#    science_program
# 65       BLOCK-102
# 66       BLOCK-102
# 67       BLOCK-102
# 68     SITCOM-1001
# 69     SITCOM-1001

# %% [markdown]
# Select exposures:

# %%
seq_nums = np.sort(np.array(df_science.seq_num))
print(seq_nums)
# Out:
# [446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463
#  464 465 466 467 468 469 470 471 472 473 474 475 476 477 478 479 480 481
#  485 486 487 488 489 490 491 492 493 494 495 496 497 498 499 500 501 502
#  503 504 505 506 507 508 509 510 511 512 513 514 515 516 546 547]

# %%
ids = np.sort(np.array(df_science.id))
print(ids)
# Out:
# [2023092600446 2023092600447 2023092600448 2023092600449 2023092600450
#  2023092600451 2023092600452 2023092600453 2023092600454 2023092600455
#  2023092600456 2023092600457 2023092600458 2023092600459 2023092600460
#  2023092600461 2023092600462 2023092600463 2023092600464 2023092600465
#  2023092600466 2023092600467 2023092600468 2023092600469 2023092600470
#  2023092600471 2023092600472 2023092600473 2023092600474 2023092600475
#  2023092600476 2023092600477 2023092600478 2023092600479 2023092600480
#  2023092600481 2023092600485 2023092600486 2023092600487 2023092600488
#  2023092600489 2023092600490 2023092600491 2023092600492 2023092600493
#  2023092600494 2023092600495 2023092600496 2023092600497 2023092600498
#  2023092600499 2023092600500 2023092600501 2023092600502 2023092600503
#  2023092600504 2023092600505 2023092600506 2023092600507 2023092600508
#  2023092600509 2023092600510 2023092600511 2023092600512 2023092600513
#  2023092600514 2023092600515 2023092600516 2023092600546 2023092600547]

# %%
min_seq = 487
max_seq = 516

# %%
seq_mask = (seq_nums>=min_seq)*(seq_nums<=max_seq)

# %%
seq_nums = seq_nums[seq_mask]
ids = ids[seq_mask]

# %%
print(seq_nums)
print(ids)
# Out:
# [487 488 489 490 491 492 493 494 495 496 497 498 499 500 501 502 503 504
#  505 506 507 508 509 510 511 512 513 514 515 516]
# [2023092600487 2023092600488 2023092600489 2023092600490 2023092600491
#  2023092600492 2023092600493 2023092600494 2023092600495 2023092600496
#  2023092600497 2023092600498 2023092600499 2023092600500 2023092600501
#  2023092600502 2023092600503 2023092600504 2023092600505 2023092600506
#  2023092600507 2023092600508 2023092600509 2023092600510 2023092600511
#  2023092600512 2023092600513 2023092600514 2023092600515 2023092600516]

# %% [markdown]
# We test retrieving one of them:

# %%
seq_num0 = seq_nums[20]
exp_id0 = ids[20]
print(exp_id0)
# Out:
# 2023092600507

# %%
test_img = butler.get('raw', dataId={'exposure': exp_id0, 'instrument': 'LATISS', 'detector': 0}, collections = calibCollections)

# %%
fig = plt.figure(figsize=(12,10))
afw_display = afwDisplay.Display(frame=fig)
afw_display.scale('linear', 'zscale',None)
afw_display.mtv(test_img.image)

# %% [markdown]
# ## Organize amplifiers

# %%
ampli_boxes = {}
ampli_names = []
for ampIdx, amp in enumerate(test_img.getDetector()):
    ampli_name_ = amp.getName()
    ampli_names.append(ampli_name_)
    xbegin = amp.getBBox().x.begin
    xend = amp.getBBox().x.end
    ybegin = amp.getBBox().y.begin
    yend = amp.getBBox().y.end
    ampli_boxes[ampli_name_] = (xbegin,xend,ybegin,yend)

# %%
ampli_boxes
# Out:
# {'C10': (0, 509, 2000, 4000),
#  'C11': (509, 1018, 2000, 4000),
#  'C12': (1018, 1527, 2000, 4000),
#  'C13': (1527, 2036, 2000, 4000),
#  'C14': (2036, 2545, 2000, 4000),
#  'C15': (2545, 3054, 2000, 4000),
#  'C16': (3054, 3563, 2000, 4000),
#  'C17': (3563, 4072, 2000, 4000),
#  'C07': (3563, 4072, 0, 2000),
#  'C06': (3054, 3563, 0, 2000),
#  'C05': (2545, 3054, 0, 2000),
#  'C04': (2036, 2545, 0, 2000),
#  'C03': (1527, 2036, 0, 2000),
#  'C02': (1018, 1527, 0, 2000),
#  'C01': (509, 1018, 0, 2000),
#  'C00': (0, 509, 0, 2000)}

# %% [markdown]
# We do the ISR on this image the same way we do it with the spectra images (i.e., we do our pseudo-postISRCCD):

# %%
# configuration
isr_config =  IsrTaskConfig()

# %%
isr_config.doDark = False
isr_config.doFlat =  False
isr_config.doFringe = False
isr_config.doDefect = True
isr_config.doLinearize = False
isr_config.doCrosstalk =  False
isr_config.doSaturationInterpolation = False
isr_config.overscan.fitType: 'MEDIAN_PER_ROW'
isr_config.doBias: True

# %%
isr_task = IsrTask(config=isr_config)

# %%
butler = dafButler.Butler(repo, collections=calibCollections)
camera = butler.get('camera', instrument=cameraName)
#bias = butler.get('bias',instrument=cameraName,detector=0)
#defects = butler.get('defects',instrument=cameraName,detector=0)

# %%
bias = butler.get("bias",instrument=cameraName, exposure= exp_id0, detector=0, collections=calibCollections)
defects = butler.get('defects',instrument=cameraName, exposure= exp_id0,detector=0,collections=calibCollections)

#fast ISR 
isr_test = isr_task.run(test_img,bias=bias,defects=defects)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Converting exposure to floating point values.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling CCD from amplifiers.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Applying bias correction.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking defects.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking non-finite (NAN, inf) value pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Widening saturation trails.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Set 322449 BAD pixels to 10.074189.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolating masked pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: No rough magnitude zero point defined for filter empty~holo4_003.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Setting rough magnitude zero point for filter empty~holo4_003: 30.500000</pre>

# %%
test_ = isr_test.exposure.image.array

# %% [markdown]
# Value range

# %%
np.min(test_.flatten())
# Out:
# -77.40706

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
_ = ax.hist(test_.flatten(),bins=100)
ax.set_yscale("log")
ax.grid()
ax.set_xlabel('ADU')
ax.set_title('Pseudo-postISRCCD')
plt.tight_layout()

# %%
center_spec = 1750
#ylim_spec = 1280
xlim_spec0 = 1660
xlim_spec1 = 1850

delta_xlim = xlim_spec1-xlim_spec0

xlim_bck00 = 1320
xlim_bck01 = xlim_bck00+delta_xlim
xlim_bck10 = 2060
xlim_bck11 = xlim_bck10+delta_xlim

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
#im = ax.imshow(isr_test.exposure.image.array,cmap="gray",origin='lower',norm=LogNorm())
im = ax.imshow(test_,cmap="gray",origin='lower',vmin=10,vmax=20)
#ax.axhline(y=ylim_spec,ls='--')
#ax.axvline(x=center_spec,ls='--',color='r')
#ax.axvline(x=xlim_spec0,ls='--',color='b')
#ax.axvline(x=xlim_spec1,ls='--',color='b')
#ax.axvline(x=xlim_bck00,ls='--',color='magenta')
#ax.axvline(x=xlim_bck01,ls='--',color='magenta')
#ax.axvline(x=xlim_bck10,ls='--',color='magenta')
#ax.axvline(x=xlim_bck11,ls='--',color='magenta')
ax.set_title('Pseudo-postISRCCD')
fig.colorbar(im,ax=ax)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
#im = ax.imshow(isr_test.exposure.image.array,cmap="gray",origin='lower',norm=LogNorm())
im = ax.imshow(test_[0:500,1500:2000],cmap="gray",origin='lower',vmin=10,vmax=200)
#ax.axhline(y=ylim_spec,ls='--')
'''
ax.axvline(x=center_spec,ls='--',color='r')
ax.axvline(x=xlim_spec0,ls='--',color='b')
ax.axvline(x=xlim_spec1,ls='--',color='b')
ax.axvline(x=xlim_bck00,ls='--',color='magenta')
ax.axvline(x=xlim_bck01,ls='--',color='magenta')
ax.axvline(x=xlim_bck10,ls='--',color='magenta')
ax.axvline(x=xlim_bck11,ls='--',color='magenta')
'''
ax.set_title('Pseudo-postISRCCD')
fig.colorbar(im,ax=ax)

# %%
spec_line_ = test_[:,center_spec]
y_ = np.arange(len(spec_line_))

zero_order = np.max(spec_line)
y_0order = y_[spec_line==zero_order][0]
ylim_spec0 = y_0order+1000
ylim_spec1 = ylim_spec0+700
ylim_spec2 = ylim_spec0+400

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.plot(y_,spec_line_)
ax.axvline(x=y_0order,ls='--',color='r')
ax.axvline(x=ylim_spec0,ls='--',color='orange')
ax.axvline(x=ylim_spec1,ls='--',color='orange')
ax.axvline(x=ylim_spec2,ls='--',color='orange')
ax.grid()
ax.set_xlabel('Pixel')
ax.set_ylabel('ADU')
# Out:
# Text(0, 0.5, 'ADU')

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
#im = ax.imshow(isr_test.exposure.image.array,cmap="gray",origin='lower',norm=LogNorm())
im = ax.imshow(test_,cmap="gray",origin='lower',vmin=10,vmax=20)

ax.axhline(y=y_0order,ls=':',color='r')
ax.axhline(y=ylim_spec0,ls=':',color='orange')
ax.axhline(y=ylim_spec1,ls=':',color='orange')
ax.axhline(y=ylim_spec2,ls=':',color='orange')

ax.axvline(x=xlim_spec0,ls='--',color='b')
ax.axvline(x=xlim_spec1,ls='--',color='b')
ax.axvline(x=xlim_bck00,ls='--',color='magenta')
ax.axvline(x=xlim_bck01,ls='--',color='magenta')
ax.axvline(x=xlim_bck10,ls='--',color='magenta')
ax.axvline(x=xlim_bck11,ls='--',color='magenta')
ax.set_title('Pseudo-postISRCCD')
fig.colorbar(im,ax=ax)

# %%
filename_out = 'spec_{0}_{1}.fits'.format(exp_id0,physical_filter.replace('~','-'))

outdir_ = os.path.join(outdir_base,outdir_label.format(obs_day))
if os.path.exists(outdir_)==False:
    os.mkdir(outdir_)
fullfilename_out = os.path.join(outdir_,filename_out)

print(f">>>>  output filename {filename_out}")

md = test_img.getMetadata().toDict()

hdr = fits.Header()
    
for key,value in md.items():
    hdr[str(key)] = value
    

# Be carefull for Spectractor, 2 hdu units are necessary

primary_hdu = fits.PrimaryHDU(header=hdr)
image_hdu = fits.ImageHDU(test_)

hdu_list = fits.HDUList([primary_hdu, image_hdu])

hdu_list.writeto(fullfilename_out,overwrite=True)

# %%
int_spec_ = np.sum(test_[ylim_spec0:ylim_spec1,xlim_spec0:xlim_spec1])
int_bck0 = np.sum(test_[ylim_spec0:ylim_spec1,xlim_bck00:xlim_bck01])
int_bck1 = np.sum(test_[ylim_spec0:ylim_spec1,xlim_bck10:xlim_bck11])
print(int_spec_,int_bck0,int_bck1)
int_bck = np.mean([int_bck0,int_bck1])
print(int_bck)
int_spec = int_spec_-int_bck
print(int_spec)

# %% [markdown]
# # Compute integral for exposure

# %%
print(seq_nums)

# %%
pos_ = np.array([-150,-150,-100,-100,-50,-50,0,0,50,50,100,100,150,150,200,200,
                 250,250,300,300,350,350,400,400,450,450,500,500,550,550])+300.
pos_ = pos_[::-1]

# %%
print(len(seq_nums),len(pos_))

# %%
ampli_boxes = {}
ampli_names = []
exp_int = {}
for i,exp_id_ in enumerate(ids):
    print(exp_id_)
    raw_img_ = butler.get('raw', dataId={'exposure': exp_id_, 'instrument': 'LATISS', 'detector': 0}, collections = calibCollections)
    print('Raw image retrieved')
    
    bias_ = butler.get("bias",instrument=cameraName, exposure= exp_id_, detector=0, collections=calibCollections)
    defects_ = butler.get('defects',instrument=cameraName, exposure= exp_id_,detector=0,collections=calibCollections)
    
    #fast ISR 
    print('Running pseudo-ISR')
    isr_img_ = isr_task.run(raw_img_,bias=bias_,defects=defects_)
    
    data_ = isr_img_.exposure.image.array
    print('-----------------')
    
    if i==0:
        for ampIdx, amp in enumerate(raw_img_.getDetector()):
            ampli_name_ = amp.getName()
            ampli_names.append(ampli_name_)
            xbegin = amp.getBBox().x.begin
            xend = amp.getBBox().x.end
            ybegin = amp.getBBox().y.begin
            yend = amp.getBBox().y.end
            ampli_boxes[ampli_name_] = (xbegin,xend,ybegin,yend)
            
            md = raw_img_.getMetadata().toDict()
    
    spec_line_ = data_[:,center_spec]
    y_ = np.arange(len(spec_line_))

    zero_order_ = np.max(spec_line_)
    y_0order_ = y_[spec_line_==zero_order_][0]
    ylim_spec0_ = y_0order_+1000
    ylim_spec1_ = ylim_spec0_+700
    ylim_spec2_ = ylim_spec0_+400
    
    
    int1_spec_bck_ = np.sum(data_[ylim_spec0_:ylim_spec1_,xlim_spec0:xlim_spec1])
    int1_bck0_ = np.sum(data_[ylim_spec0_:ylim_spec1_,xlim_bck00:xlim_bck01])
    int1_bck1_ = np.sum(data_[ylim_spec0_:ylim_spec1_,xlim_bck10:xlim_bck11])
    print(int1_spec_bck_,int1_bck0_,int1_bck1_)
    int1_bck_ = np.mean([int1_bck0_,int1_bck1_])
    print(int1_bck_)
    int1_spec_ = int1_spec_bck_-int1_bck_
    print(int1_spec_)
    
    int2_spec_bck_ = np.sum(data_[ylim_spec0_:ylim_spec2_,xlim_spec0:xlim_spec1])
    int2_bck0_ = np.sum(data_[ylim_spec0_:ylim_spec2_,xlim_bck00:xlim_bck01])
    int2_bck1_ = np.sum(data_[ylim_spec0_:ylim_spec2_,xlim_bck10:xlim_bck11])
    print(int2_spec_bck_,int2_bck0_,int2_bck1_)
    int2_bck_ = np.mean([int2_bck0_,int2_bck1_])
    print(int2_bck_)
    int2_spec_ = int2_spec_bck_-int2_bck_
    print(int2_spec_)
    
    exp_int[exp_id_] = (y_0order_,int1_spec_,int2_spec_)
    
    del(raw_img_)
    del(bias_)
    del(defects_)
    del(isr_img_)

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
for i,exp_id_ in enumerate(ids):
    if i%2==0:
        color = 'b'
    else:
        color = 'r'
    ax.scatter(exp_int[exp_id_][0],exp_int[exp_id_][1],marker='o',color=color)
    ax.scatter(exp_int[exp_id_][0],exp_int[exp_id_][2],marker='x',color=color)
    
    print(i,exp_id_,exp_int[exp_id_][0],exp_int[exp_id_][1],exp_int[exp_id_][2])
ax.grid()
ax.set_xlim(0,1000)
ax.set_xlabel('Position')
ax.set_ylabel('Sum')
plt.tight_layout()
