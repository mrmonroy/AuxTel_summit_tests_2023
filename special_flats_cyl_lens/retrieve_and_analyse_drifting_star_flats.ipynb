# %%
import os
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import matplotlib.dates as mdates

import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.visualization import (MinMaxInterval, SqrtStretch,ZScaleInterval,PercentileInterval,
                                   ImageNormalize,imshow_norm)
from astropy.visualization.stretch import SinhStretch, LinearStretch,AsinhStretch,LogStretch


from astropy.io import fits

# %%
# Assembly task
# https://github.com/lsst/ip_isr/blob/main/python/lsst/ip/isr/isrTask.py

from lsst.ip.isr.assembleCcdTask import (AssembleCcdConfig, AssembleCcdTask)
from lsst.ip.isr.isrTask import (IsrTask, IsrTaskConfig)

#https://github.com/lsst/ip_isr/blob/main/python/lsst/ip/isr/overscan.py
from lsst.ip.isr import  OverscanCorrectionTaskConfig, OverscanCorrectionTask

# %%
# LSST Display
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
! eups list -s
# Out:
# afw                   g5b0a815229+07073039e0 	current w_2023_35 setup
# alert_packet          gc1f99d08cb 	current w_2023_35 setup
# analysis_drp          gfadca26dcd+7df23b908a 	current w_2023_35 setup
# analysis_tools        g1887775915+12c68b5962 	current w_2023_35 setup
# ap_association        g6758148a95+cc00875cc0 	current w_2023_35 setup
# ap_pipe               g06c608b3b8+b6810408d8 	current w_2023_35 setup
# ap_verify             g3bba7c13bf+c1b85e1378 	current w_2023_35 setup
# astro_metadata_translator g0978aabd1f+2a7d2c9fe3 	current w_2023_35 setup
# astshim               g3273194fdb+f6908454ef 	current w_2023_35 setup
# atmospec              LOCAL:/home/m/monroy/repos/repos_w_2023_35/atmospec 	setup
# base                  g98ffbb4407+81bc2a20b4 	current w_2023_35 setup
# cbp                   ga32fcf49c8+ea6441928c 	current w_2023_35 setup
# coadd_utils           g337abbeb29+ea6441928c 	current w_2023_35 setup
# cp_pipe               g857a3418e4+7df23b908a 	current w_2023_35 setup
# cp_verify             ge14ceffff4+12c68b5962 	current w_2023_35 setup
# cpputils              g9ddcbc5298+7f7571301f 	current w_2023_35 setup
# ctrl_bps              gf871a26735+9b83f7e51d 	current w_2023_35 setup
# ctrl_bps_htcondor     g4bda180e2e+6e30524a5b 	current w_2023_35 setup
# ctrl_bps_panda        g72cefa85e0+6e30524a5b 	current w_2023_35 setup
# ctrl_bps_parsl        gfe186b85dc+6e30524a5b 	current w_2023_35 setup
# ctrl_execute          g3288a415c1+d78986aaf7 	current w_2023_35 setup
# ctrl_mpexec           g183f8e0c68+0b5ff14b26 	current w_2023_35 setup
# ctrl_platform_s3df    g3be6bbf6ee+b8e28c3ebe 	current w_2023_35 setup
# daf_base              gf041782ebf+2691319615 	current w_2023_35 setup
# daf_butler            g11710eee44+2396472d69 	current w_2023_35 setup
# daf_relation          g8a20fa5453+e358f92434 	current w_2023_35 setup
# dax_apdb              g4c90b7bd52+fc57afb704 	current w_2023_35 setup
# display_astrowidgets  g2bbee38e9b+ea6441928c 	current w_2023_35 setup
# display_ds9           gdb4ec4c597+ea6441928c 	current w_2023_35 setup
# display_firefly       gae46bcf261+ea6441928c 	current w_2023_35 setup
# display_matplotlib    g0265f82a02+ea6441928c 	current w_2023_35 setup
# drp_pipe              g62dbaf9afa+539581bbb4 	current w_2023_35 setup
# drp_tasks             geb290cab21+7b56d25c6a 	current w_2023_35 setup
# dustmaps_cachedata    gbb0a0c949e+81bc2a20b4 	current w_2023_35 setup
# eups                  LOCAL:/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/eups 	setup
# faro                  ge8614a52ae+e4940fcbf0 	current w_2023_35 setup
# felis                 g56b87fd2ae+81bc2a20b4 	current w_2023_35 setup
# fgcm                  g8d9a5b0805 	current w_2023_35 setup
# fgcmcal               g023b260a0e+25821a5130 	current w_2023_35 setup
# gbdes                 gc329cc8a54 	current w_2023_35 setup
# geom                  ga1e77700b3+1440987d3f 	current w_2023_35 setup
# ip_diffim             g07994bdeae+16b1756208 	current w_2023_35 setup
# ip_isr                gba31a79951+9acc3d8d25 	current w_2023_35 setup
# jointcal              g3c689f2686+4a33454177 	current w_2023_35 setup
# jointcal_cholmod      g81a980c3dd+81bc2a20b4 	current w_2023_35 setup
# kht                   gafcb7142de 	current w_2023_35 setup
# log                   g1e7d6db67d+e358f92434 	current w_2023_35 setup
# lsst_apps             ga3d9597cd8+b074b31d98 	current w_2023_35 setup
# lsst_bps_plugins      g3a590c521e+29bb66eb6d 	current w_2023_35 setup
# lsst_distrib          g4213664e8e+c55b99ec95 	current w_2023_35 setup
# lsst_obs              gea673b7ed9+130b2f5ea4 	current w_2023_35 setup
# meas_algorithms       g6f40f426a6+f7136a40d1 	current w_2023_35 setup
# meas_astrom           g0a0026dc87+9acc3d8d25 	current w_2023_35 setup
# meas_base             g67924a670a+edc5793283 	current w_2023_35 setup
# meas_deblender        g2cc88a2952+6327360372 	current w_2023_35 setup
# meas_extensions_convolved g42fff21dfb+94f62ec815 	current w_2023_35 setup
# meas_extensions_gaap  g8dd6597355+dceeeb951c 	current w_2023_35 setup
# meas_extensions_photometryKron gb2715bf1a1+9acc3d8d25 	current w_2023_35 setup
# meas_extensions_piff  gc86a011abf+9acc3d8d25 	current w_2023_35 setup
# meas_extensions_psfex g58be5f913a+32f1932512 	current w_2023_35 setup
# meas_extensions_scarlet g943cb464a2+f79590064d 	current w_2023_35 setup
# meas_extensions_shapeHSM g571dde35ae+9acc3d8d25 	current w_2023_35 setup
# meas_extensions_simpleShape gcf0d15dbbd+f7136a40d1 	current w_2023_35 setup
# meas_extensions_trailedSources g47da3c6c86+f7136a40d1 	current w_2023_35 setup
# meas_modelfit         g93c4d6e787+79b822255a 	current w_2023_35 setup
# meas_transiNet        g2ca692352a+f7136a40d1 	current w_2023_35 setup
# obs_base              gcc620a9fd9+e9a6d3d3e6 	current w_2023_35 setup
# obs_cfht              g98ea1558ea+7a1fade221 	current w_2023_35 setup
# obs_decam             gcd84e84c5d+9bde498c3c 	current w_2023_35 setup
# obs_decam_data        g9eeeb5e174 	current w_2023_35 setup
# obs_lsst              g18ae76373f+3c91ea642d 	current w_2023_35 setup
# obs_lsst_data         g5736ae6652 	current w_2023_35 setup
# obs_subaru            g65833fab06+f9c311f76a 	current w_2023_35 setup
# obs_subaru_data       g7ff78db354 	current w_2023_35 setup
# pex_config            g22560d942e+2a7d2c9fe3 	current w_2023_35 setup
# pex_exceptions        gdaeeff99f8+0d8dbea60f 	current w_2023_35 setup
# pipe_base             g6bb983e87d+fa056e98be 	current w_2023_35 setup
# pipe_tasks            g68a3911fdd+6ad9f154ac 	current w_2023_35 setup
# proxmin               g33b4157f25 	current w_2023_35 setup
# psfex                 gc054bea089+81bc2a20b4 	current w_2023_35 setup
# resources             g9e435448e7+e358f92434 	current w_2023_35 setup
# scarlet               g63ff1f842d+4083830bf8 	current w_2023_35 setup
# scarlet_extensions    g9d18589735+d445b4966c 	current w_2023_35 setup
# sconsUtils            g80c3e6a29f 	current w_2023_35 setup
# sdm_schemas           g9797f2168b 	current w_2023_35 setup
# shapelet              g44018dc512+ea6441928c 	current w_2023_35 setup
# skymap                g37c6e7c3d5+905c2c68d7 	current w_2023_35 setup
# spectractor           LOCAL:/home/m/monroy/repos/repos_w_2023_35/Spectractor 	setup
# sphgeom               g6ae5381d9b+81bc2a20b4 	current w_2023_35 setup
# utils                 gf0e1c1abb1+81bc2a20b4 	current w_2023_35 setup
# verify                gffb8816710+02c788d496 	current w_2023_35 setup
# verify_metrics        gd129bed42c+81bc2a20b4 	current w_2023_35 setup

# %% [markdown]
# # Butler

# %%
import lsst.daf.butler as dafButler

# %%
embargo = True

# %%
if embargo:
    repo="/sdf/group/rubin/repo/oga/"
else:
    repo = "/sdf/group/rubin/repo/main"
butler = dafButler.Butler(repo)
registry = butler.registry

# %%
cameraName = 'LATISS'
calibCollections = ['LATISS/defaults','LATISS/raw/all']
for col in registry.queryCollections("*LATISS/calib*"):
    #print(col)
    calibCollections.append(col)

# %% [markdown]
# # Paths

# %%
outdir_base = 'output_fits/'
if os.path.exists(outdir_base)==False:
    os.mkdir(outdir_base)
outdir_label = 'cyl_lens_flat_{0}/'

# %% [markdown]
# We check the different dimension records existing for *physical_filter*:

# %%
phys_filters = list(registry.queryDimensionRecords('physical_filter',where="instrument='LATISS'"))

# %% [markdown]
# Print physical_filters with hologram in place:

# %%
for f_ in phys_filters:
    if 'holo' in f_.name:
        print(f_.name)
# Out:
# empty~holo4_003
# blank_bk7_wg05~holo4_003
# KPNO_1111_436nm~holo4_003
# KPNO_373A_677nm~holo4_003
# KPNO_406_828nm~holo4_003
# unknown~holo4_003
# BG40~holo4_003
# quadnotch1~holo4_003
# RG610~holo4_003
# FELH0600~holo4_003
# SDSSg~holo4_003
# SDSSr~holo4_003
# SDSSi~holo4_003
# BG40_65mm_1~holo4_003
# BG40_65mm_2~holo4_003
# OG550_65mm_1~holo4_003
# OG550_65mm_2~holo4_003
# SDSSg_65mm~holo4_003
# SDSSr_65mm~holo4_003
# SDSSi_65mm~holo4_003
# SDSSu_65mm~holo4_003
# SDSSz_65mm~holo4_003
# SDSSy_65mm~holo4_003
# empty~holo4_001
# blank_bk7_wg05~holo4_001
# KPNO_1111_436nm~holo4_001
# KPNO_373A_677nm~holo4_001
# KPNO_406_828nm~holo4_001
# unknown~holo4_001
# BG40~holo4_001
# BG40_65mm_1~holo4_001
# BG40_65mm_2~holo4_001
# quadnotch1~holo4_001
# RG610~holo4_001
# OG550_65mm_1~holo4_001
# OG550_65mm_2~holo4_001
# FELH0600~holo4_001
# SDSSg~holo4_001
# SDSSr~holo4_001
# SDSSi~holo4_001
# SDSSu_65mm~holo4_001
# SDSSg_65mm~holo4_001
# SDSSr_65mm~holo4_001
# SDSSi_65mm~holo4_001
# SDSSz_65mm~holo4_001
# SDSSy_65mm~holo4_001
# collimator~holo4_003
# collimator~holo4_001
# cyl_lens~holo4_003
# cyl_lens~holo4_001

# %%
obs_type = 'science'
obs_day = 20230215
physical_filter = 'cyl_lens~holo4_003' #Note that there are no exposure with this config for the moment

# %%
df_science = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num','time_start',
                                    'time_end' ,'type', 'target','filter_disp','zenith_angle',
                                    'expos','ra','dec','skyangle','science_program'])

# %%
#where_exps = "instrument='LATISS' AND exposure.observation_type='{0}' AND exposure.day_obs={1} AND physical_filter='{2}'".format(obs_type,obs_day,physical_filter)
where_exps = "instrument='LATISS' AND exposure.observation_type='{0}' AND exposure.day_obs={1}".format(obs_type,obs_day)
for i, info in enumerate(registry.queryDimensionRecords('exposure',where=where_exps)):
    
    #if info.observation_type=='science':
    id_ = info.id
    obs_id_ = info.obs_id
    day_obs_ = info.day_obs
    seq_num_ = info.seq_num
    timespan_ = info.timespan
    timespan_begin_ = pd.to_datetime(timespan_.begin.to_string())
    timespan_end_ = pd.to_datetime(timespan_.end.to_string())
    timespan_begin_jd_ = timespan_.begin.jd
    timespan_begin_mjd_ = timespan_.begin.mjd

    observation_type_ = info.observation_type
    target_name_ = info.target_name
    physical_filter_ = info.physical_filter
    zenith_angle_ = info.zenith_angle
    exposure_time_ = info.exposure_time
    tracking_ra_ = info.tracking_ra
    tracking_dec_ = info.tracking_dec
    sky_angle_ = info.sky_angle
    science_program_ = info.science_program

    df_science.loc[i] = [id_, obs_id_, day_obs_, seq_num_,timespan_begin_,timespan_end_ ,observation_type_, \
                         target_name_, physical_filter_, zenith_angle_, exposure_time_,tracking_ra_, \
                         tracking_dec_, sky_angle_, science_program_]

    if i < 2:
        print(i)
        print(info)
        print("\t timespan:            ",info.timespan)
        print("\t timespan.begin:      ",info.timespan.begin)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
        print("-----------------------------------------------------")
# Out:
# 0
# exposure:
#   instrument: 'LATISS'
#   id: 2023021500236
#   physical_filter: 'SDSSr_65mm~empty'
#   obs_id: 'AT_O_20230215_000236'
#   exposure_time: 1.0
#   dark_time: 1.2411
#   observation_type: 'science'
#   observation_reason: 'object'
#   day_obs: 20230215
#   seq_num: 236
#   seq_start: 236
#   seq_end: 236
#   group_name: '2023-02-16T01:07:25.241'
#   group_id: 2564392452410000
#   target_name: 'HD25025'
#   science_program: 'unknown'
#   tracking_ra: 59.509266282087005
#   tracking_dec: -13.505257465867974
#   sky_angle: 214.8946079090418
#   azimuth: 292.2695592645051
#   zenith_angle: 34.101158096725364
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2023-02-16 01:07:35.505985', scale='tai', format='iso'), end=astropy.time.Time('2023-02-16 01:07:36.747000', scale='tai', format='iso'))
# 	 timespan:             [2023-02-16T01:07:35.505985, 2023-02-16T01:07:36.747000)
# 	 timespan.begin:       2023-02-16 01:07:35.505985
# 	 id:                   2023021500236
# 	 day_obs:              20230215
# 	 seq_num:              236
# 	 type-of-observation:  science
# 	 target:               HD25025
# -----------------------------------------------------
# 1
# exposure:
#   instrument: 'LATISS'
#   id: 2023021500237
#   physical_filter: 'SDSSr_65mm~empty'
#   obs_id: 'AT_O_20230215_000237'
#   exposure_time: 1.0
#   dark_time: 1.24023
#   observation_type: 'science'
#   observation_reason: 'object'
#   day_obs: 20230215
#   seq_num: 237
#   seq_start: 237
#   seq_end: 237
#   group_name: '2023-02-16T01:08:39.432'
#   group_id: 2564393194320000
#   target_name: 'HD25025'
#   science_program: 'unknown'
#   tracking_ra: 59.57129280862077
#   tracking_dec: -13.513415268142905
#   sky_angle: 214.89498114728644
#   azimuth: 292.01061313269156
#   zenith_angle: 34.29763531838995
#   has_simulated: False
#   timespan: Timespan(begin=astropy.time.Time('2023-02-16 01:08:50.111012', scale='tai', format='iso'), end=astropy.time.Time('2023-02-16 01:08:51.352000', scale='tai', format='iso'))
# 	 timespan:             [2023-02-16T01:08:50.111012, 2023-02-16T01:08:51.352000)
# 	 timespan.begin:       2023-02-16 01:08:50.111012
# 	 id:                   2023021500237
# 	 day_obs:              20230215
# 	 seq_num:              237
# 	 type-of-observation:  science
# 	 target:               HD25025
# -----------------------------------------------------

# %%
print('Number of entries = ',len(df_science))
# Out:
# Number of entries =  389

# %%
df_science.tail(5)
# Out:
#                 id                obs_id   day_obs  seq_num  \
# 384  2023021500755  AT_O_20230215_000755  20230215      755
# 385  2023021500756  AT_O_20230215_000756  20230215      756
# 386  2023021500757  AT_O_20230215_000757  20230215      757
# 387  2023021500758  AT_O_20230215_000758  20230215      758
# 388  2023021500759  AT_O_20230215_000759  20230215      759
#
#                     time_start                time_end     type    target  \
# 384 2023-02-16 07:28:02.006997 2023-02-16 07:28:32.238  science  E5-A_010
# 385 2023-02-16 07:28:46.502994 2023-02-16 07:29:16.734  science  E5-A_010
# 386 2023-02-16 07:29:19.209998 2023-02-16 07:29:49.442  science  E5-A_010
# 387 2023-02-16 07:30:04.856984 2023-02-16 07:30:35.099  science  E5-A_010
# 388 2023-02-16 07:30:37.575012 2023-02-16 07:31:07.829  science  E5-A_010
#
#           filter_disp  zenith_angle  expos          ra        dec    skyangle  \
# 384  SDSSi_65mm~empty     16.355978   30.0  180.595065 -45.784026  359.998518
# 385  SDSSg_65mm~empty     16.401310   30.0  180.595023 -45.784011  359.998586
# 386  SDSSg_65mm~empty     16.436042   30.0  180.595007 -45.783998  359.998518
# 387  SDSSr_65mm~empty     16.485513   30.0  180.595036 -45.784002  359.998551
# 388  SDSSr_65mm~empty     16.520654   30.0  180.595033 -45.784011  359.998568
#
#         science_program
# 384  AUXTEL_DRP_IMAGING
# 385  AUXTEL_DRP_IMAGING
# 386  AUXTEL_DRP_IMAGING
# 387  AUXTEL_DRP_IMAGING
# 388  AUXTEL_DRP_IMAGING

# %% [markdown]
# Select exposures:
#
# ### For the moment, we take the sequence numbers corresponding to the fits files that were given to us

# %%
seq_nums = np.arange(276,281)
print(seq_nums)
# Out:
# [276 277 278 279 280]

# %% [markdown]
# We test retrieving one of them:

# %%
seq_num0 = seq_nums[0]
exp_id0 = str(obs_day)+'00'+str(seq_num0)
exp_id0 = int(exp_id0)
print(exp_id0)
# Out:
# 2023021500276

# %%
test_img = butler.get('raw', dataId={'exposure': exp_id0, 'instrument': 'LATISS', 'detector': 0}, collections = calibCollections)

# %%
fig = plt.figure(figsize=(12,10))
afw_display = afwDisplay.Display(frame=fig)
afw_display.scale('linear', 'zscale',None)
afw_display.mtv(test_img.image)

# %% [markdown]
# We do the ISR on this image the same way we do it with the spectra images (i.e., we do our pseudo-postISRCCD):

# %%
# configuration
isr_config =  IsrTaskConfig()

# %%
isr_config.doDark = False
isr_config.doFlat =  False
isr_config.doFringe = False
isr_config.doDefect = True
isr_config.doLinearize = False
isr_config.doCrosstalk =  False
isr_config.doSaturationInterpolation = False
isr_config.overscan.fitType: 'MEDIAN_PER_ROW'
isr_config.doBias: True

# %%
isr_task = IsrTask(config=isr_config)

# %%
butler = dafButler.Butler(repo, collections=calibCollections)
camera = butler.get('camera', instrument=cameraName)
#bias = butler.get('bias',instrument=cameraName,detector=0)
#defects = butler.get('defects',instrument=cameraName,detector=0)

# %%
bias = butler.get("bias",instrument=cameraName, exposure= exp_id0, detector=0, collections=calibCollections)
defects = butler.get('defects',instrument=cameraName, exposure= exp_id0,detector=0,collections=calibCollections)

#fast ISR 
isr_test = isr_task.run(test_img,bias=bias,defects=defects)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Converting exposure to floating point values.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling CCD from amplifiers.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Applying bias correction.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking defects.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking non-finite (NAN, inf) value pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Widening saturation trails.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Set 322444 BAD pixels to 882.160004.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolating masked pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: No rough magnitude zero point defined for filter empty~holo4_003.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Setting rough magnitude zero point for filter empty~holo4_003: 32.885606</pre>

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
im = ax.imshow(isr_test.exposure.image.array,cmap="gray",origin='lower',norm=LogNorm())
fig.colorbar(im,ax=ax)

# %% [markdown]
# # Create sum exposure from individual exposures
#
# ## 1. Do pseudo-postISRCCD

# %%
print(seq_nums)
# Out:
# [276 277 278 279 280]

# %%
exp_list = []
ampli_boxes = {}
ampli_names = []
for i,num_ in enumerate(seq_nums):
    exp_id_ = str(obs_day)+'00'+str(num_)
    exp_id_ = int(exp_id_)
    print(exp_id_)
    raw_img_ = butler.get('raw', dataId={'exposure': exp_id_, 'instrument': 'LATISS', 'detector': 0}, collections = calibCollections)
    print('Raw image retrieved')
    
    bias_ = butler.get("bias",instrument=cameraName, exposure= exp_id_, detector=0, collections=calibCollections)
    defects_ = butler.get('defects',instrument=cameraName, exposure= exp_id_,detector=0,collections=calibCollections)
    
    #fast ISR 
    print('Running pseudo-ISR')
    isr_img_ = isr_task.run(raw_img_,bias=bias_,defects=defects_)
    
    exp_list.append(isr_img_)
    print('-----------------')
    
    if i==0:
        for ampIdx, amp in enumerate(raw_img_.getDetector()):
            ampli_name_ = amp.getName()
            ampli_names.append(ampli_name_)
            xbegin = amp.getBBox().x.begin
            xend = amp.getBBox().x.end
            ybegin = amp.getBBox().y.begin
            yend = amp.getBBox().y.end
            ampli_boxes[ampli_name_] = (xbegin,xend,ybegin,yend)
            
            md = raw_img_.getMetadata().toDict()
# Out:
# 2023021500276
# Raw image retrieved
# Running pseudo-ISR
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Converting exposure to floating point values.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling CCD from amplifiers.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Applying bias correction.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking defects.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking non-finite (NAN, inf) value pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Widening saturation trails.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Set 322444 BAD pixels to 882.160004.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolating masked pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: No rough magnitude zero point defined for filter empty~holo4_003.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Setting rough magnitude zero point for filter empty~holo4_003: 32.885606</pre>
# -----------------
# 2023021500277
# Raw image retrieved
# Running pseudo-ISR
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Converting exposure to floating point values.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling CCD from amplifiers.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Applying bias correction.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking defects.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking non-finite (NAN, inf) value pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Widening saturation trails.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Set 322444 BAD pixels to 873.955383.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolating masked pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: No rough magnitude zero point defined for filter empty~holo4_003.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Setting rough magnitude zero point for filter empty~holo4_003: 32.885606</pre>
# -----------------
# 2023021500278
# Raw image retrieved
# Running pseudo-ISR
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Converting exposure to floating point values.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling CCD from amplifiers.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Applying bias correction.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking defects.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking non-finite (NAN, inf) value pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Widening saturation trails.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Set 322444 BAD pixels to 880.833923.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolating masked pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: No rough magnitude zero point defined for filter empty~holo4_003.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Setting rough magnitude zero point for filter empty~holo4_003: 32.885606</pre>
# -----------------
# 2023021500279
# Raw image retrieved
# Running pseudo-ISR
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Converting exposure to floating point values.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling CCD from amplifiers.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Applying bias correction.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking defects.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking non-finite (NAN, inf) value pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Widening saturation trails.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Set 322444 BAD pixels to 886.195892.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolating masked pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: No rough magnitude zero point defined for filter empty~holo4_003.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Setting rough magnitude zero point for filter empty~holo4_003: 32.885606</pre>
# -----------------
# 2023021500280
# Raw image retrieved
# Running pseudo-ISR
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Converting exposure to floating point values.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling CCD from amplifiers.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Applying bias correction.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking defects.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Masking non-finite (NAN, inf) value pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Widening saturation trails.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Set 322444 BAD pixels to 881.568604.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Interpolating masked pixels.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: No rough magnitude zero point defined for filter empty~holo4_003.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.isr</span> <span style="color: var(--jp-info-color0)">INFO</span>: Setting rough magnitude zero point for filter empty~holo4_003: 32.885606</pre>
# -----------------

# %%
ampli_boxes
# Out:
# {'C10': (0, 509, 2000, 4000),
#  'C11': (509, 1018, 2000, 4000),
#  'C12': (1018, 1527, 2000, 4000),
#  'C13': (1527, 2036, 2000, 4000),
#  'C14': (2036, 2545, 2000, 4000),
#  'C15': (2545, 3054, 2000, 4000),
#  'C16': (3054, 3563, 2000, 4000),
#  'C17': (3563, 4072, 2000, 4000),
#  'C07': (3563, 4072, 0, 2000),
#  'C06': (3054, 3563, 0, 2000),
#  'C05': (2545, 3054, 0, 2000),
#  'C04': (2036, 2545, 0, 2000),
#  'C03': (1527, 2036, 0, 2000),
#  'C02': (1018, 1527, 0, 2000),
#  'C01': (509, 1018, 0, 2000),
#  'C00': (0, 509, 0, 2000)}

# %%
mapampid = [0,1,2,3,4,5,6,7,15,14,13,12,11,10,9,8]

# %%
num_amplis = len(mapampid)

# %% [markdown]
# ## 2. Wavelength (row) normalization
#
# We test the normalization with one exposure

# %%
exp0 = exp_list[0].exposure.image.array

# %%
print(exp0.shape)
# Out:
# (4000, 4072)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
_ = ax.hist(exp0.flatten(),bins=1000)
mu = np.mean(exp0.flatten())
sigma = np.std(exp0.flatten())
nsigma = 0.5
ax.axvline(x=mu-nsigma*sigma,ls='--',color='r')
ax.axvline(x=mu+nsigma*sigma,ls='--',color='r')
ax.set_xlim(mu-2.*sigma,mu+2.*sigma)
ax.grid()

# %%
vmin = 1
vmax = 6000

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
im = ax.imshow(exp0,cmap="gray",origin='lower',vmin=vmin,vmax=vmax)#,norm=LogNorm())
fig.colorbar(im,ax=ax)
for key in ampli_boxes.keys():
    ax.axvline(x=ampli_boxes[key][0])
    ax.axvline(x=ampli_boxes[key][1])
    ax.axhline(y=ampli_boxes[key][2])
    ax.axhline(y=ampli_boxes[key][3])
ax.set_xlim(0,4072)
ax.set_ylim(0,4000)
# Out:
# (0.0, 4000.0)

# %% [markdown]
# Visualize data per amplifier separately

# %%
fig = plt.figure(figsize=(20,12))

for i,key in enumerate(ampli_boxes.keys()):
    x0 = ampli_boxes[key][0]
    x1 = ampli_boxes[key][1]
    y0 = ampli_boxes[key][2]
    y1 = ampli_boxes[key][3]
    ampli_ = exp0[y0:y1,x0:x1]
    
    ax = fig.add_subplot(2,8,mapampid[i]+1)
    im = ax.imshow(ampli_,cmap="gray",origin='lower',vmin=vmin,vmax=vmax)#,norm=LogNorm())
    yticks = ax.get_yticks()
    #print(yticks)
    ax.set_yticks(ticks=yticks[1:],labels=yticks[1:].astype('int')+y0)
    ax.set_title(key)

# %% [markdown]
# We normalize each row (per amplifier) to their median value. This way, we can compare exposure with different number counts (due to different effective exposure times)

# %%
fig = plt.figure(figsize=(20,12))

for i,key in enumerate(ampli_boxes.keys()):
    x0 = ampli_boxes[key][0]
    x1 = ampli_boxes[key][1]
    y0 = ampli_boxes[key][2]
    y1 = ampli_boxes[key][3]
    ampli_ = exp0[y0:y1,x0:x1]
    median_ = np.median(ampli_,axis=1)
    
    norm_ampli_ = ampli_/median_[:,None]
    print(norm_ampli_.shape)
    
    ax = fig.add_subplot(2,8,mapampid[i]+1)
    im = ax.imshow(norm_ampli_,cmap="gray",origin='lower',norm=LogNorm())
    yticks = ax.get_yticks()
    #print(yticks)
    ax.set_yticks(ticks=yticks[1:],labels=yticks[1:].astype('int')+y0)
    ax.set_title(key)
# Out:
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)

# %% [markdown]
# Now we do this systematically for all exposures and we combine taking their median pixel by pixel

# %%
print(len(exp_list))
# Out:
# 5

# %%
special_flat_ = []
for i,exp_ in enumerate(exp_list):
    print(i)
    data_ = exp_.exposure.image.array
    print(data_.shape)
    
    out_ = np.zeros(data_.shape)
    for key in ampli_boxes.keys():
        x0 = ampli_boxes[key][0]
        x1 = ampli_boxes[key][1]
        y0 = ampli_boxes[key][2]
        y1 = ampli_boxes[key][3]
        ampli_ = data_[y0:y1,x0:x1]
        median_ = np.median(ampli_,axis=1)

        norm_ampli_ = ampli_/median_[:,None]
        print(norm_ampli_.shape)
        
        out_[y0:y1,x0:x1] = norm_ampli_
    print(out_.shape)
    special_flat_.append(out_)
    print('-------------')
special_flat_ = np.array(special_flat_)
print(special_flat_.shape)
# Out:
# 0
# (4000, 4072)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (4000, 4072)
# -------------
# 1
# (4000, 4072)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (4000, 4072)
# -------------
# 2
# (4000, 4072)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (4000, 4072)
# -------------
# 3
# (4000, 4072)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (4000, 4072)
# -------------
# 4
# (4000, 4072)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (2000, 509)
# (4000, 4072)
# -------------
# (5, 4000, 4072)

# %%
fig = plt.figure(figsize=(20,12))

for i,key in enumerate(ampli_boxes.keys()):
    x0 = ampli_boxes[key][0]
    x1 = ampli_boxes[key][1]
    y0 = ampli_boxes[key][2]
    y1 = ampli_boxes[key][3]
    ampli_ = special_flat_[0][y0:y1,x0:x1]
    
    ax = fig.add_subplot(2,8,mapampid[i]+1)
    im = ax.imshow(ampli_,cmap="gray",origin='lower',norm=LogNorm())
    yticks = ax.get_yticks()
    #print(yticks)
    ax.set_yticks(ticks=yticks[1:],labels=yticks[1:].astype('int')+y0)
    ax.set_title(key)

# %% [markdown]
# ## 3. Compute median of individual exposures and combine into one

# %%
special_flat = np.median(special_flat_,axis=0)

# %%
print(special_flat.shape)
# Out:
# (4000, 4072)

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
im = ax.imshow(special_flat,cmap="gray",origin='lower',norm=LogNorm())
fig.colorbar(im,ax=ax)
for key in ampli_boxes.keys():
    ax.axvline(x=ampli_boxes[key][0])
    ax.axvline(x=ampli_boxes[key][1])
    ax.axhline(y=ampli_boxes[key][2])
    ax.axhline(y=ampli_boxes[key][3])
ax.set_xlim(0,4072)
ax.set_ylim(0,4000)
# Out:
# (0.0, 4000.0)

# %% [markdown]
# # Save in fits file

# %%
outdir_ = outdir_label.format(obs_day)
outdir = os.path.join(outdir_base,outdir_)
if os.path.exists(outdir)==False:
    os.mkdir(outdir)

# %%
filename_out = 'cyl_lens_flat_{0}.fits'.format(obs_day)
fullfilename_out = os.path.join(outdir,filename_out)

print(f">>>>  output filename {filename_out}")

hdr = fits.Header()
    
for key,value in md.items():
    hdr[str(key)] = value
    

# Be carefull for Spectractor, 2 hdu units are necessary

primary_hdu = fits.PrimaryHDU(header=hdr)
image_hdu = fits.ImageHDU(special_flat)

hdu_list = fits.HDUList([primary_hdu, image_hdu])

hdu_list.writeto(fullfilename_out,overwrite=True)
# Out:
# >>>>  output filename cyl_lens_flat_20230215.fits
